# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_law_count = pd.read_csv('../data/entrepreneurship_law_count.csv', engine='python')
df_law_count.shape
# Out:
# (9690, 17)

# %%
df_law_count.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       ID      economy wbcodev2  \
# 0           0             0               0  AFG1971  Afghanistan      AFG
# 1           1             1               1  AFG1972  Afghanistan      AFG
# 2           2             2               2  AFG1973  Afghanistan      AFG
# 3           3             3               3  AFG1974  Afghanistan      AFG
# 4           4             4               4  AFG1975  Afghanistan      AFG
#
#        Region Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP  \
# 0  South Asia   Low income      1971       26.3                75
# 1  South Asia   Low income      1972       26.3                75
# 2  South Asia   Low income      1973       26.3                75
# 3  South Asia   Low income      1974       26.3                75
# 4  South Asia   Low income      1975       26.3                75
#
#   sign_contract register_business open_bank_account  \
# 0           Yes               Yes               Yes
# ...

# %%
def sign_contract_count(counter):
    if (counter['sign_contract'] == 'Yes') | (counter['sign_contract'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["sign_contract_count"] = df_law_count.apply(sign_contract_count, axis=1)

# %%
def register_business_count(counter):
    if (counter['register_business'] == 'Yes') | (counter['register_business'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["register_business_count"] = df_law_count.apply(register_business_count, axis=1)

# %%
def open_bank_account_count(counter):
    if (counter['open_bank_account'] == 'Yes') | (counter['open_bank_account'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["open_bank_account_count"] = df_law_count.apply(open_bank_account_count, axis=1)

# %%
def discrimination_credit_prohibited_count(counter):
    if (counter['discrimination_credit_prohibited'] == 'Yes') | (counter['discrimination_credit_prohibited'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["discrimination_credit_prohibited_count"] = df_law_count.apply(discrimination_credit_prohibited_count, axis=1)

# %%
df_law_count.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       ID      economy wbcodev2  \
# 0           0             0               0  AFG1971  Afghanistan      AFG
# 1           1             1               1  AFG1972  Afghanistan      AFG
# 2           2             2               2  AFG1973  Afghanistan      AFG
# 3           3             3               3  AFG1974  Afghanistan      AFG
# 4           4             4               4  AFG1975  Afghanistan      AFG
#
#        Region Income_group  reportyr  WBL INDEX  ...  sign_contract  \
# 0  South Asia   Low income      1971       26.3  ...            Yes
# 1  South Asia   Low income      1972       26.3  ...            Yes
# 2  South Asia   Low income      1973       26.3  ...            Yes
# 3  South Asia   Low income      1974       26.3  ...            Yes
# 4  South Asia   Low income      1975       26.3  ...            Yes
#
#   register_business open_bank_account discrimination_credit_prohibited  \
# ...

# %%
df_law_count
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       ID      economy wbcodev2  \
# 0              0             0               0  AFG1971  Afghanistan      AFG
# 1              1             1               1  AFG1972  Afghanistan      AFG
# 2              2             2               2  AFG1973  Afghanistan      AFG
# 3              3             3               3  AFG1974  Afghanistan      AFG
# 4              4             4               4  AFG1975  Afghanistan      AFG
# ...          ...           ...             ...      ...          ...      ...
# 9685        9685          9685            9685  ZWE2017     Zimbabwe      ZWE
# 9686        9686          9686            9686  ZWE2018     Zimbabwe      ZWE
# 9687        9687          9687            9687  ZWE2019     Zimbabwe      ZWE
# 9688        9688          9688            9688  ZWE2020     Zimbabwe      ZWE
# 9689        9689          9689            9689  ZWE2021     Zimbabwe      ZWE
#
# ...

# %%
df_law_count=df_law_count.drop(columns = ['law_count'])

# %%
df_law_count
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       ID      economy wbcodev2  \
# 0              0             0               0  AFG1971  Afghanistan      AFG
# 1              1             1               1  AFG1972  Afghanistan      AFG
# 2              2             2               2  AFG1973  Afghanistan      AFG
# 3              3             3               3  AFG1974  Afghanistan      AFG
# 4              4             4               4  AFG1975  Afghanistan      AFG
# ...          ...           ...             ...      ...          ...      ...
# 9685        9685          9685            9685  ZWE2017     Zimbabwe      ZWE
# 9686        9686          9686            9686  ZWE2018     Zimbabwe      ZWE
# 9687        9687          9687            9687  ZWE2019     Zimbabwe      ZWE
# 9688        9688          9688            9688  ZWE2020     Zimbabwe      ZWE
# 9689        9689          9689            9689  ZWE2021     Zimbabwe      ZWE
#
# ...

# %%
df_law_count=df_law_count.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])

# %%
df_law_count
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_law_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      9690 non-null   object
#  1   economy                                 9690 non-null   object
#  2   wbcodev2                                9690 non-null   object
#  3   Region                                  9690 non-null   object
#  4   Income_group                            9690 non-null   object
#  5   reportyr                                9690 non-null   int64
#  6   WBL INDEX                               9690 non-null   float64
#  7   ENTREPRENEURSHIP                        9690 non-null   int64
#  8   sign_contract                           9690 non-null   object
#  9   register_business                       9690 non-null   object
# ...

# %%
df_law_count['sign_contract_count'] = df_law_count['sign_contract_count'].astype('str')

# %%
df_law_count['sign_contract_count'] = df_law_count['sign_contract_count'].astype('int')

# %%
df_law_count['register_business_count'] = df_law_count['register_business_count'].astype('str')

# %%
df_law_count['register_business_count'] = df_law_count['register_business_count'].astype('int')

# %%
df_law_count['open_bank_account_count'] = df_law_count['open_bank_account_count'].astype('str')

# %%
df_law_count['open_bank_account_count'] = df_law_count['open_bank_account_count'].astype('int')

# %%
df_law_count['discrimination_credit_prohibited_count'] = df_law_count['discrimination_credit_prohibited_count'].astype('str')

# %%
df_law_count['discrimination_credit_prohibited_count'] = df_law_count['discrimination_credit_prohibited_count'].astype('int')

# %%
df_law_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      9690 non-null   object
#  1   economy                                 9690 non-null   object
#  2   wbcodev2                                9690 non-null   object
#  3   Region                                  9690 non-null   object
#  4   Income_group                            9690 non-null   object
#  5   reportyr                                9690 non-null   int64
#  6   WBL INDEX                               9690 non-null   float64
#  7   ENTREPRENEURSHIP                        9690 non-null   int64
#  8   sign_contract                           9690 non-null   object
#  9   register_business                       9690 non-null   object
# ...

# %%
df_law_count['total_law_counts'] = df_law_count['sign_contract_count']+df_law_count['register_business_count']+df_law_count['open_bank_account_count']+df_law_count['discrimination_credit_prohibited_count']

# %%
df_law_count['total_law_counts'] = df_law_count['total_law_counts'].astype('str')

# %%
df_law_count['total_law_counts'] = df_law_count['total_law_counts'].astype('int')

# %%
df_law_count
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
total_law_value_count = df_law_count.total_law_counts.value_counts()
total_law_value_count
# Out:
# 3    7307
# 4    1249
# 0     557
# 2     517
# 1      60
# Name: total_law_counts, dtype: int64

# %%
sign_contract_value_count = df_law_count.sign_contract_count.value_counts()
sign_contract_value_count
# Out:
# 1    9124
# 0     566
# Name: sign_contract_count, dtype: int64

# %%
register_business_value_count = df_law_count.register_business_count.value_counts()
register_business_value_count
# Out:
# 1    8880
# 0     810
# Name: register_business_count, dtype: int64

# %%
open_bank_account_value_count = df_law_count.open_bank_account_count.value_counts()
open_bank_account_value_count
# Out:
# 1    8757
# 0     933
# Name: open_bank_account_count, dtype: int64

# %%
discrimination_credit_prohibited_value_count = df_law_count.discrimination_credit_prohibited_count.value_counts()
discrimination_credit_prohibited_value_count
# Out:
# 0    8440
# 1    1250
# Name: discrimination_credit_prohibited_count, dtype: int64

# %%
average_law_count_by_income = (df_law_count.groupby(['Income_group'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income
# Out:
#           Income_group  total_law_counts
# 0          High income          3.193137
# 1           Low income          2.534314
# 2  Lower middle income          2.802745
# 3  Upper middle income          2.818250

# %%
average_law_count_by_income_period = (df_law_count.groupby(['Income_group', 'period'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income_period
# Out:
#            Income_group     period  total_law_counts
# 0           High income  1971-1975          2.770000
# 1           High income  1976-1980          2.956667
# 2           High income  1981-1985          3.020000
# 3           High income  1986-1990          3.033333
# 4           High income  1991-1995          3.096667
# 5           High income  1996-2000          3.146667
# 6           High income  2001-2005          3.213333
# 7           High income  2006-2010          3.393333
# 8           High income  2011-2015          3.586667
# 9           High income  2016-2021          3.627778
# 10           Low income  1971-1975          2.185714
# 11           Low income  1976-1980          2.250000
# 12           Low income  1981-1985          2.400000
# 13           Low income  1986-1990          2.464286
# 14           Low income  1991-1995          2.500000
# 15           Low income  1996-2000          2.514286
# 16           Low income  2001-2005          2.535714
# ...

# %%
plt.bar(average_law_count_by_income_period.period, average_law_count_by_income_period.total_law_counts, linewidth=2, color='#a45c7c'),
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Average Law Count')
plt.title('Average Law Count over period')
plt.show()

# %%
plt.scatter(average_law_count_by_income_period.period, average_law_count_by_income_period.total_law_counts, linewidth=2, color='#a45c7c'),
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Average Law Count')
plt.title('Average Law Count over period')
plt.show()

# %%
average_law_count_by_region = (df_law_count.groupby(['Region'], as_index=False)['total_law_counts'].mean())
average_law_count_by_region
# Out:
#                        Region  total_law_counts
# 0         East Asia & Pacific          2.968627
# 1       Europe & Central Asia          3.163683
# 2           High income: OECD          3.245675
# 3   Latin America & Caribbean          2.957721
# 4  Middle East & North Africa          3.064706
# 5                  South Asia          2.875000
# 6          Sub-Saharan Africa          2.353350

# %%
average_law_count_by_economy = (df_law_count.groupby(['economy'], as_index=False)['total_law_counts'].mean())
average_law_count_by_economy
# Out:
#                  economy  total_law_counts
# 0            Afghanistan          3.000000
# 1                Albania          3.215686
# 2                Algeria          3.000000
# 3                 Angola          2.117647
# 4    Antigua and Barbuda          3.000000
# ..                   ...               ...
# 185              Vietnam          3.274510
# 186   West Bank and Gaza          3.000000
# 187          Yemen, Rep.          3.000000
# 188               Zambia          3.098039
# 189             Zimbabwe          2.901961
#
# [190 rows x 2 columns]

# %%
average_law_count_by_economy = average_law_count_by_economy.sort_values(by = 'total_law_counts', ascending = False)
average_law_count_by_economy
# Out:
#                 economy  total_law_counts
# 136  Puerto Rico (U.S.)          3.901961
# 180       United States          3.901961
# 179      United Kingdom          3.882353
# 30               Canada          3.862745
# 183             Vanuatu          3.764706
# ..                  ...               ...
# 147        Sierra Leone          0.705882
# 170         Timor-Leste          0.686275
# 37     Congo, Dem. Rep.          0.333333
# 54             Eswatini          0.000000
# 51    Equatorial Guinea          0.000000
#
# [190 rows x 2 columns]

# %%
average_law_count_by_economy.head(15)
# Out:
#                   economy  total_law_counts
# 136    Puerto Rico (U.S.)          3.901961
# 180         United States          3.901961
# 179        United Kingdom          3.882353
# 30                 Canada          3.862745
# 183               Vanuatu          3.764706
# 7               Australia          3.725490
# 58                 France          3.549020
# 120           New Zealand          3.529412
# 119           Netherlands          3.529412
# 45               Djibouti          3.509804
# 72   Hong Kong SAR, China          3.490196
# 69                 Guyana          3.450980
# 132                  Peru          3.431373
# 79                Ireland          3.411765
# 80                 Israel          3.411765

# %%
average_law_count_by_economy.tail(15)
# Out:
#                economy  total_law_counts
# 59               Gabon          2.000000
# 32                Chad          2.000000
# 5            Argentina          1.941176
# 33               Chile          1.823529
# 161           Suriname          1.568627
# 117            Namibia          1.470588
# 68       Guinea-Bissau          1.000000
# 115         Mozambique          1.000000
# 21            Botswana          0.941176
# 95             Lesotho          0.882353
# 147       Sierra Leone          0.705882
# 170        Timor-Leste          0.686275
# 37    Congo, Dem. Rep.          0.333333
# 54            Eswatini          0.000000
# 51   Equatorial Guinea          0.000000

# %%
average_law_count_by_income_period = (df_law_count.groupby(['Income_group', 'period'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income_period
# Out:
#            Income_group     period  total_law_counts
# 0           High income  1971-1975          2.770000
# 1           High income  1976-1980          2.956667
# 2           High income  1981-1985          3.020000
# 3           High income  1986-1990          3.033333
# 4           High income  1991-1995          3.096667
# 5           High income  1996-2000          3.146667
# 6           High income  2001-2005          3.213333
# 7           High income  2006-2010          3.393333
# 8           High income  2011-2015          3.586667
# 9           High income  2016-2021          3.627778
# 10           Low income  1971-1975          2.185714
# 11           Low income  1976-1980          2.250000
# 12           Low income  1981-1985          2.400000
# 13           Low income  1986-1990          2.464286
# 14           Low income  1991-1995          2.500000
# 15           Low income  1996-2000          2.514286
# 16           Low income  2001-2005          2.535714
# ...

# %%
#labels = month_2020_df.Month
#calls_2019 = month_2019_df.number_calls
#calls_2020 = month_2020_df.number_calls

#x = np.arange(len(labels))  # the label locations
#width = 0.35  # the width of the bars
#fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/2, calls_2019, width, color='#a45c7c', label='2019')
#rects2 = ax.bar(x + width/2, calls_2020, width, color='#E97223', label='2020')
#plt.rcParams["figure.figsize"] = [15,10]


# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_ylabel('Call Volume')
#ax.set_title('2019 vs 2020 Call Volumes')
#ax.set_xticks(x)
#ax.set_xticklabels(labels)
#ax.legend()
#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)
#fig.tight_layout();

# %%
#def period(counter):
    #if (counter['reportyr'] == 1971) | (counter['reportyr'] <= 1975) :
        #return '1971-1975'
    #if (counter['reportyr'] == 1976) | (counter['reportyr'] <= 1980) :
        #return '1976-1980'
    #if (counter['reportyr'] == 1981) | (counter['reportyr'] <= 1985) :
        #return '1981-1985'
    #if (counter['reportyr'] == 1986) | (counter['reportyr'] <= 1990) :
        #return '1986-1990'
    #if (counter['reportyr'] == 1991) | (counter['reportyr'] <= 1995) :
        #return '1991-1995'
    #if (counter['reportyr'] == 1996) | (counter['reportyr'] <= 2000) :
        #return '1996-2000'
    #if (counter['reportyr'] == 2001) | (counter['reportyr'] <= 2005) :
        #return '2001-2005'
    #if (counter['reportyr'] == 2006) | (counter['reportyr'] <= 2010) :
        #return '2006-2010'
    #if (counter['reportyr'] == 2011) | (counter['reportyr'] <= 2015) :
        #return '2011-2015'
    #else:
        #return '2016-2021'

#df_entrepreneur["period"] = df_entrepreneur.apply(period, axis=1)

# %%
df_average_1971 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1971-1975']
df_average_1971 = df_average_1971.sort_values(by = 'total_law_counts', ascending = False)
df_average_1971
# Out:
#            Income_group     period  total_law_counts
# 0           High income  1971-1975          2.770000
# 30  Upper middle income  1971-1975          2.480769
# 20  Lower middle income  1971-1975          2.384000
# 10           Low income  1971-1975          2.185714

# %%
df_average_1976 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1976-1980']
df_average_1976 = df_average_1976.sort_values(by = 'total_law_counts', ascending = False)
df_average_1976
# Out:
#            Income_group     period  total_law_counts
# 1           High income  1976-1980          2.956667
# 31  Upper middle income  1976-1980          2.550000
# 21  Lower middle income  1976-1980          2.456000
# 11           Low income  1976-1980          2.250000

# %%
df_average_1981 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1981-1985']
df_average_1981 = df_average_1981.sort_values(by = 'total_law_counts', ascending = False)
df_average_1981
# Out:
#            Income_group     period  total_law_counts
# 2           High income  1981-1985          3.020000
# 32  Upper middle income  1981-1985          2.626923
# 22  Lower middle income  1981-1985          2.592000
# 12           Low income  1981-1985          2.400000

# %%
df_average_1986 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1986-1990']
df_average_1986 = df_average_1986.sort_values(by = 'total_law_counts', ascending = False)
df_average_1986
# Out:
#            Income_group     period  total_law_counts
# 3           High income  1986-1990          3.033333
# 23  Lower middle income  1986-1990          2.688000
# 33  Upper middle income  1986-1990          2.657692
# 13           Low income  1986-1990          2.464286

# %%
df_average_1991 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1991-1995']
df_average_1991 = df_average_1991.sort_values(by = 'total_law_counts', ascending = False)
df_average_1991
# Out:
#            Income_group     period  total_law_counts
# 4           High income  1991-1995          3.096667
# 24  Lower middle income  1991-1995          2.772000
# 34  Upper middle income  1991-1995          2.711538
# 14           Low income  1991-1995          2.500000

# %%
df_average_1996 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1996-2000']
df_average_1996 = df_average_1996.sort_values(by = 'total_law_counts', ascending = False)
df_average_1996
# Out:
#            Income_group     period  total_law_counts
# 5           High income  1996-2000          3.146667
# 35  Upper middle income  1996-2000          2.830769
# 25  Lower middle income  1996-2000          2.804000
# 15           Low income  1996-2000          2.514286

# %%
df_average_2001 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2001-2005']
df_average_2001 = df_average_2001.sort_values(by = 'total_law_counts', ascending = False)
df_average_2001
# Out:
#            Income_group     period  total_law_counts
# 6           High income  2001-2005          3.213333
# 36  Upper middle income  2001-2005          2.915385
# 26  Lower middle income  2001-2005          2.824000
# 16           Low income  2001-2005          2.535714

# %%
df_average_2006 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2006-2010']
df_average_2006 = df_average_2006.sort_values(by = 'total_law_counts', ascending = False)
df_average_2006
# Out:
#            Income_group     period  total_law_counts
# 7           High income  2006-2010          3.393333
# 27  Lower middle income  2006-2010          3.016000
# 37  Upper middle income  2006-2010          3.011538
# 17           Low income  2006-2010          2.700000

# %%
df_average_2011 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2011-2015']
df_average_2011 = df_average_2011.sort_values(by = 'total_law_counts', ascending = False)
df_average_2011
# Out:
#            Income_group     period  total_law_counts
# 8           High income  2011-2015          3.586667
# 28  Lower middle income  2011-2015          3.160000
# 38  Upper middle income  2011-2015          3.123077
# 18           Low income  2011-2015          2.785714

# %%
df_average_2016 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2016-2021']
df_average_2016 = df_average_2016.sort_values(by = 'total_law_counts', ascending = False)
df_average_2016
# Out:
#            Income_group     period  total_law_counts
# 9           High income  2016-2021          3.627778
# 29  Lower middle income  2016-2021          3.243333
# 39  Upper middle income  2016-2021          3.198718
# 19           Low income  2016-2021          2.928571

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(nrows = 4, ncols = 3, sharey=True, figsize=(15,15))
#fig.subplots_adjust(wspace=0.05)
#plt.figure(figsize=(25,45))
fig.suptitle('Average Law Counts in 1971-2021 by Income Group', fontsize=26)
ax1.set_title('1971-1975')
ax1.bar(df_average_1971.Income_group, df_average_1971.total_law_counts)#, color='green',edgecolor='black', label='28,501')
#ax1.set_xticks(range(1,31, 1))

ax2.bar(df_average_1976.Income_group, df_average_1976.total_law_counts)#, edgecolor='black', label='5,972,641')
ax2.set_title('1976-1980')
#ax2.axvline(x=25, color='g')


ax3.bar(df_average_1981.Income_group, df_average_1981.total_law_counts)
ax3.set_title('1981-1985')


ax4.bar(df_average_1986.Income_group, df_average_1986.total_law_counts)
ax4.set_title('1986-1990')


ax5.bar(df_average_1991.Income_group, df_average_1991.total_law_counts)
ax5.set_title('1991-1995')

ax6.bar(df_average_1996.Income_group, df_average_1996.total_law_counts)
ax6.set_title('1996-2000')


ax7.bar(df_average_2001.Income_group, df_average_2001.total_law_counts)
ax7.set_title('2001-2005')

ax8.bar(df_average_2006.Income_group, df_average_2006.total_law_counts)
ax8.set_title('2006-2010')
#ax8.axvline(x=7, color='red') # I added a vertical red bar here because they received the highest # of call -93-

ax9.bar(df_average_2011.Income_group, df_average_2011.total_law_counts)
ax9.set_title('2011-2015')

ax10.bar(df_average_2016.Income_group, df_average_2016.total_law_counts)
ax10.set_title('2016-2021')


#fig.text(0.48, -0.01, 'columns name', fontsize=20, ha='center')
#fig.text(0.04, 0.5, 'Count', va='center', rotation='vertical', fontsize=20)
#fig.legend(loc="upper left", fontsize=20)
#plt.axhline(y=350, linestyle='--', color='red', label = 'Weekday average')
#plt.axvline(x=38, color='red')
plt.yticks(fontsize=60)
plt.xticks(rotation = 70)
plt.show();
