# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_law_count = pd.read_csv('../data/entrepreneurship_periods.csv', engine='python')
df_law_count.shape
# Out:
# (9500, 15)

# %%
#df_law_count = pd.read_csv('../data/entrepreneurship_law_count.csv', engine='python')
#df_law_count.shape

# %%
df_law_count.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       ID      economy wbcodev2      Region  \
# 0           1             1  AFG1972  Afghanistan      AFG  South Asia
# 1           2             2  AFG1973  Afghanistan      AFG  South Asia
# 2           3             3  AFG1974  Afghanistan      AFG  South Asia
# 3           4             4  AFG1975  Afghanistan      AFG  South Asia
# 4           5             5  AFG1976  Afghanistan      AFG  South Asia
#
#   Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract  \
# 0   Low income      1972       26.3                75           Yes
# 1   Low income      1973       26.3                75           Yes
# 2   Low income      1974       26.3                75           Yes
# 3   Low income      1975       26.3                75           Yes
# 4   Low income      1976       26.3                75           Yes
#
#   register_business open_bank_account discrimination_credit_prohibited  \
# ...

# %%
def sign_contract_count(counter):
    if (counter['sign_contract'] == 'Yes') | (counter['sign_contract'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["sign_contract_count"] = df_law_count.apply(sign_contract_count, axis=1)

# %%
def register_business_count(counter):
    if (counter['register_business'] == 'Yes') | (counter['register_business'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["register_business_count"] = df_law_count.apply(register_business_count, axis=1)

# %%
def open_bank_account_count(counter):
    if (counter['open_bank_account'] == 'Yes') | (counter['open_bank_account'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["open_bank_account_count"] = df_law_count.apply(open_bank_account_count, axis=1)

# %%
def discrimination_credit_prohibited_count(counter):
    if (counter['discrimination_credit_prohibited'] == 'Yes') | (counter['discrimination_credit_prohibited'] == 'Yes') :
        return '1'
    else:
        return '0'

df_law_count["discrimination_credit_prohibited_count"] = df_law_count.apply(discrimination_credit_prohibited_count, axis=1)

# %%
df_law_count.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       ID      economy wbcodev2      Region  \
# 0           1             1  AFG1972  Afghanistan      AFG  South Asia
# 1           2             2  AFG1973  Afghanistan      AFG  South Asia
# 2           3             3  AFG1974  Afghanistan      AFG  South Asia
# 3           4             4  AFG1975  Afghanistan      AFG  South Asia
# 4           5             5  AFG1976  Afghanistan      AFG  South Asia
#
#   Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract  \
# 0   Low income      1972       26.3                75           Yes
# 1   Low income      1973       26.3                75           Yes
# 2   Low income      1974       26.3                75           Yes
# 3   Low income      1975       26.3                75           Yes
# 4   Low income      1976       26.3                75           Yes
#
#   register_business open_bank_account discrimination_credit_prohibited  \
# ...

# %%
df_law_count
# Out:
#       Unnamed: 0  Unnamed: 0.1       ID      economy wbcodev2  \
# 0              1             1  AFG1972  Afghanistan      AFG
# 1              2             2  AFG1973  Afghanistan      AFG
# 2              3             3  AFG1974  Afghanistan      AFG
# 3              4             4  AFG1975  Afghanistan      AFG
# 4              5             5  AFG1976  Afghanistan      AFG
# ...          ...           ...      ...          ...      ...
# 9495        9685          9685  ZWE2017     Zimbabwe      ZWE
# 9496        9686          9686  ZWE2018     Zimbabwe      ZWE
# 9497        9687          9687  ZWE2019     Zimbabwe      ZWE
# 9498        9688          9688  ZWE2020     Zimbabwe      ZWE
# 9499        9689          9689  ZWE2021     Zimbabwe      ZWE
#
#                   Region         Income_group  reportyr  WBL INDEX  \
# 0             South Asia           Low income      1972       26.3
# 1             South Asia           Low income      1973       26.3
# ...

# %%
df_law_count.economy.value_counts()
# Out:
# Oman             50
# Paraguay         50
# Korea, Rep.      50
# Venezuela, RB    50
# Armenia          50
#                  ..
# Bhutan           50
# Somalia          50
# Austria          50
# Lithuania        50
# Fiji             50
# Name: economy, Length: 190, dtype: int64

# %%
df_law_count
# Out:
#       Unnamed: 0  Unnamed: 0.1       ID      economy wbcodev2  \
# 0              1             1  AFG1972  Afghanistan      AFG
# 1              2             2  AFG1973  Afghanistan      AFG
# 2              3             3  AFG1974  Afghanistan      AFG
# 3              4             4  AFG1975  Afghanistan      AFG
# 4              5             5  AFG1976  Afghanistan      AFG
# ...          ...           ...      ...          ...      ...
# 9495        9685          9685  ZWE2017     Zimbabwe      ZWE
# 9496        9686          9686  ZWE2018     Zimbabwe      ZWE
# 9497        9687          9687  ZWE2019     Zimbabwe      ZWE
# 9498        9688          9688  ZWE2020     Zimbabwe      ZWE
# 9499        9689          9689  ZWE2021     Zimbabwe      ZWE
#
#                   Region         Income_group  reportyr  WBL INDEX  \
# 0             South Asia           Low income      1972       26.3
# 1             South Asia           Low income      1973       26.3
# ...

# %%
df_law_count=df_law_count.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df_law_count
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1972  Afghanistan      AFG          South Asia           Low income
# 1     AFG1973  Afghanistan      AFG          South Asia           Low income
# 2     AFG1974  Afghanistan      AFG          South Asia           Low income
# 3     AFG1975  Afghanistan      AFG          South Asia           Low income
# 4     AFG1976  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9495  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9496  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9497  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9498  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9499  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
income_group_list = {}
for inc in df_law_count['Income_group']:
    if inc in income_group_list.keys():
       income_group_list[inc] += 1
    else:
        income_group_list[inc] = 1
income_group_list
# Out:
# {'Low income': 1400,
#  'Lower middle income': 2500,
#  'Upper middle income': 2600,
#  'High income': 3000}

# %%
income_groups = (df_law_count.groupby(['period'], as_index=False)['economy'].count())
income_groups
# Out:
#       period  economy
# 0  1972-1976      950
# 1  1977-1981      950
# 2  1982-1986      950
# 3  1987-1991      950
# 4  1992-1996      950
# 5  1997-2001      950
# 6  2002-2006      950
# 7  2007-2011      950
# 8  2012-2016      950
# 9  2017-2021      950

# %%
income_groups_1972_1976 = df_law_count.loc[df_law_count['period'] == '1972-1976']
income_groups_1977_1981 = df_law_count.loc[df_law_count['period'] == '1977-1981']
income_groups_1982_1986 = df_law_count.loc[df_law_count['period'] == '1982-1986']
income_groups_1987_1991 = df_law_count.loc[df_law_count['period'] == '1987-1991']
income_groups_1992_1996 = df_law_count.loc[df_law_count['period'] == '1992-1996']
income_groups_1997_2001 = df_law_count.loc[df_law_count['period'] == '1997-2001']
income_groups_2002_2006 = df_law_count.loc[df_law_count['period'] == '2002-2006']
income_groups_2007_2011 = df_law_count.loc[df_law_count['period'] == '2007-2011']
income_groups_2012_2016 = df_law_count.loc[df_law_count['period'] == '2012-2016']
income_groups_2017_2021 = df_law_count.loc[df_law_count['period'] == '2017-2021']

# %%
income_groups_1972_1976.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_1977_1981.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_1982_1986.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_1987_1991.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_1992_1996.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_1997_2001.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_2002_2006.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_2007_2011.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_2012_2016.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
income_groups_2017_2021.Income_group.value_counts()
# Out:
# High income            300
# Upper middle income    260
# Lower middle income    250
# Low income             140
# Name: Income_group, dtype: int64

# %%
df_law_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9500 entries, 0 to 9499
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      9500 non-null   object
#  1   economy                                 9500 non-null   object
#  2   wbcodev2                                9500 non-null   object
#  3   Region                                  9500 non-null   object
#  4   Income_group                            9500 non-null   object
#  5   reportyr                                9500 non-null   int64
#  6   WBL INDEX                               9500 non-null   float64
#  7   ENTREPRENEURSHIP                        9500 non-null   int64
#  8   sign_contract                           9500 non-null   object
#  9   register_business                       9500 non-null   object
# ...

# %%
df_law_count['sign_contract_count'] = df_law_count['sign_contract_count'].astype('str')

# %%
df_law_count['sign_contract_count'] = df_law_count['sign_contract_count'].astype('int')

# %%
df_law_count['register_business_count'] = df_law_count['register_business_count'].astype('str')

# %%
df_law_count['register_business_count'] = df_law_count['register_business_count'].astype('int')

# %%
df_law_count['open_bank_account_count'] = df_law_count['open_bank_account_count'].astype('str')

# %%
df_law_count['open_bank_account_count'] = df_law_count['open_bank_account_count'].astype('int')

# %%
df_law_count['discrimination_credit_prohibited_count'] = df_law_count['discrimination_credit_prohibited_count'].astype('str')

# %%
df_law_count['discrimination_credit_prohibited_count'] = df_law_count['discrimination_credit_prohibited_count'].astype('int')

# %%
df_law_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9500 entries, 0 to 9499
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      9500 non-null   object
#  1   economy                                 9500 non-null   object
#  2   wbcodev2                                9500 non-null   object
#  3   Region                                  9500 non-null   object
#  4   Income_group                            9500 non-null   object
#  5   reportyr                                9500 non-null   int64
#  6   WBL INDEX                               9500 non-null   float64
#  7   ENTREPRENEURSHIP                        9500 non-null   int64
#  8   sign_contract                           9500 non-null   object
#  9   register_business                       9500 non-null   object
# ...

# %%
df_law_count['total_law_counts'] = df_law_count['sign_contract_count']+df_law_count['register_business_count']+df_law_count['open_bank_account_count']+df_law_count['discrimination_credit_prohibited_count']

# %%
df_law_count['total_law_counts'] = df_law_count['total_law_counts'].astype('str')

# %%
df_law_count['total_law_counts'] = df_law_count['total_law_counts'].astype('int')

# %%
df_law_count
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1972  Afghanistan      AFG          South Asia           Low income
# 1     AFG1973  Afghanistan      AFG          South Asia           Low income
# 2     AFG1974  Afghanistan      AFG          South Asia           Low income
# 3     AFG1975  Afghanistan      AFG          South Asia           Low income
# 4     AFG1976  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9495  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9496  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9497  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9498  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9499  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_law_count_1 = df_law_count.loc[df_law_count['total_law_counts'] == 1]
df_law_count_1.head()
# Out:
#            ID        economy wbcodev2              Region Income_group  \
# 3150  GNB1972  Guinea-Bissau      GNB  Sub-Saharan Africa   Low income
# 3151  GNB1973  Guinea-Bissau      GNB  Sub-Saharan Africa   Low income
# 3152  GNB1974  Guinea-Bissau      GNB  Sub-Saharan Africa   Low income
# 3153  GNB1975  Guinea-Bissau      GNB  Sub-Saharan Africa   Low income
# 3154  GNB1976  Guinea-Bissau      GNB  Sub-Saharan Africa   Low income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# 3150      1972       28.1                25           Yes                No
# 3151      1973       28.1                25           Yes                No
# 3152      1974       28.1                25           Yes                No
# 3153      1975       28.1                25           Yes                No
# 3154      1976       28.1                25           Yes                No
#
#      open_bank_account discrimination_credit_prohibited     period  \
# ...

# %%
economy_count_1_list = df_law_count_1['economy'].to_list
economy_count_1_list
# Out:
# <bound method IndexOpsMixin.tolist of 3150       Guinea-Bissau
# 3151       Guinea-Bissau
# 3152       Guinea-Bissau
# 3153       Guinea-Bissau
# 3154       Guinea-Bissau
# 3155       Guinea-Bissau
# 3156       Guinea-Bissau
# 3157       Guinea-Bissau
# 3158       Guinea-Bissau
# 3159       Guinea-Bissau
# 3160       Guinea-Bissau
# 3161       Guinea-Bissau
# 3162       Guinea-Bissau
# 3163       Guinea-Bissau
# 3164       Guinea-Bissau
# 3165       Guinea-Bissau
# 3166       Guinea-Bissau
# 3167       Guinea-Bissau
# 3168       Guinea-Bissau
# 3169       Guinea-Bissau
# 3170       Guinea-Bissau
# 3171       Guinea-Bissau
# 3172       Guinea-Bissau
# 3173       Guinea-Bissau
# 3174       Guinea-Bissau
# 3175       Guinea-Bissau
# 3176       Guinea-Bissau
# 3177       Guinea-Bissau
# 3178       Guinea-Bissau
# 3179       Guinea-Bissau
# 3180       Guinea-Bissau
# 3181       Guinea-Bissau
# 3182       Guinea-Bissau
# 3183       Guinea-Bissau
# 3184       Guinea-Bissau
# ...

# %%
count_1_list = {}
for one in df_law_count_1['economy']:
    if one in count_1_list.keys():
       count_1_list[one] += 1
    else:
        count_1_list[one] = 1
count_1_list
# Out:
# {'Guinea-Bissau': 50, 'Timor-Leste': 8, 'Congo, Dem. Rep.': 1}

# %%
df_law_count_2 = df_law_count.loc[df_law_count['total_law_counts'] == 2]
df_law_count_2.head()
# Out:
#           ID economy wbcodev2              Region         Income_group  \
# 600  BEN1972   Benin      BEN  Sub-Saharan Africa  Lower middle income
# 601  BEN1973   Benin      BEN  Sub-Saharan Africa  Lower middle income
# 602  BEN1974   Benin      BEN  Sub-Saharan Africa  Lower middle income
# 603  BEN1975   Benin      BEN  Sub-Saharan Africa  Lower middle income
# 604  BEN1976   Benin      BEN  Sub-Saharan Africa  Lower middle income
#
#      reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# 600      1972       28.1                50           Yes               Yes
# 601      1973       28.1                50           Yes               Yes
# 602      1974       37.5                50           Yes               Yes
# 603      1975       40.0                50           Yes               Yes
# 604      1976       40.0                50           Yes               Yes
#
#     open_bank_account discrimination_credit_prohibited     period  \
# ...

# %%
df_law_count_3 = df_law_count.loc[df_law_count['total_law_counts'] == 3]
df_law_count_3.head()
# Out:
#         ID      economy wbcodev2      Region Income_group  reportyr  \
# 0  AFG1972  Afghanistan      AFG  South Asia   Low income      1972
# 1  AFG1973  Afghanistan      AFG  South Asia   Low income      1973
# 2  AFG1974  Afghanistan      AFG  South Asia   Low income      1974
# 3  AFG1975  Afghanistan      AFG  South Asia   Low income      1975
# 4  AFG1976  Afghanistan      AFG  South Asia   Low income      1976
#
#    WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# 0       26.3                75           Yes               Yes
# 1       26.3                75           Yes               Yes
# 2       26.3                75           Yes               Yes
# 3       26.3                75           Yes               Yes
# 4       26.3                75           Yes               Yes
#
#   open_bank_account discrimination_credit_prohibited     period  \
# 0               Yes                               No  1972-1976
# ...

# %%
df_law_count_4 = df_law_count.loc[df_law_count['total_law_counts'] == 4]
df_law_count_4.head()
# Out:
#          ID economy wbcodev2              Region         Income_group  \
# 91  AGO2013  Angola      AGO  Sub-Saharan Africa  Lower middle income
# 92  AGO2014  Angola      AGO  Sub-Saharan Africa  Lower middle income
# 93  AGO2015  Angola      AGO  Sub-Saharan Africa  Lower middle income
# 94  AGO2016  Angola      AGO  Sub-Saharan Africa  Lower middle income
# 95  AGO2017  Angola      AGO  Sub-Saharan Africa  Lower middle income
#
#     reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# 91      2013       70.6               100           Yes               Yes
# 92      2014       70.6               100           Yes               Yes
# 93      2015       70.6               100           Yes               Yes
# 94      2016       70.6               100           Yes               Yes
# 95      2017       73.1               100           Yes               Yes
#
#    open_bank_account discrimination_credit_prohibited     period  \
# ...

# %%
total_law_value_count = df_law_count.total_law_counts.value_counts()
total_law_value_count
# Out:
# 3    7159
# 4    1249
# 0     528
# 2     505
# 1      59
# Name: total_law_counts, dtype: int64

# %%
sign_contract_value_count = df_law_count.sign_contract_count.value_counts()
sign_contract_value_count
# Out:
# 1    8963
# 0     537
# Name: sign_contract_count, dtype: int64

# %%
register_business_value_count = df_law_count.register_business_count.value_counts()
register_business_value_count
# Out:
# 1    8723
# 0     777
# Name: register_business_count, dtype: int64

# %%
open_bank_account_value_count = df_law_count.open_bank_account_count.value_counts()
open_bank_account_value_count
# Out:
# 1    8606
# 0     894
# Name: open_bank_account_count, dtype: int64

# %%
discrimination_credit_prohibited_value_count = df_law_count.discrimination_credit_prohibited_count.value_counts()
discrimination_credit_prohibited_value_count
# Out:
# 0    8250
# 1    1250
# Name: discrimination_credit_prohibited_count, dtype: int64

# %%
average_law_count_by_income = (df_law_count.groupby(['Income_group'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income
# Out:
#           Income_group  total_law_counts
# 0          High income          3.202000
# 1           Low income          2.542143
# 2  Lower middle income          2.811600
# 3  Upper middle income          2.826154

# %%
average_law_count_by_income_period = (df_law_count.groupby(['Income_group', 'period'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income_period
# Out:
#            Income_group     period  total_law_counts
# 0           High income  1972-1976          2.796667
# 1           High income  1977-1981          2.983333
# 2           High income  1982-1986          3.023333
# 3           High income  1987-1991          3.043333
# 4           High income  1992-1996          3.106667
# 5           High income  1997-2001          3.156667
# 6           High income  2002-2006          3.233333
# 7           High income  2007-2011          3.450000
# 8           High income  2012-2016          3.593333
# 9           High income  2017-2021          3.633333
# 10           Low income  1972-1976          2.207143
# 11           Low income  1977-1981          2.271429
# 12           Low income  1982-1986          2.421429
# 13           Low income  1987-1991          2.471429
# 14           Low income  1992-1996          2.500000
# 15           Low income  1997-2001          2.521429
# 16           Low income  2002-2006          2.564286
# ...

# %%
group_by_law_count_by_income_period = (df_law_count.groupby(['Income_group', 'period'], as_index=False)['total_law_counts'].count())
group_by_law_count_by_income_period
# Out:
#            Income_group     period  total_law_counts
# 0           High income  1972-1976               300
# 1           High income  1977-1981               300
# 2           High income  1982-1986               300
# 3           High income  1987-1991               300
# 4           High income  1992-1996               300
# 5           High income  1997-2001               300
# 6           High income  2002-2006               300
# 7           High income  2007-2011               300
# 8           High income  2012-2016               300
# 9           High income  2017-2021               300
# 10           Low income  1972-1976               140
# 11           Low income  1977-1981               140
# 12           Low income  1982-1986               140
# 13           Low income  1987-1991               140
# 14           Low income  1992-1996               140
# 15           Low income  1997-2001               140
# 16           Low income  2002-2006               140
# ...

# %%
plt.bar(average_law_count_by_income_period.period, average_law_count_by_income_period.total_law_counts, linewidth=2, color='#a45c7c'),
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Average Law Count')
plt.title('Average Law Count over period')
plt.show()

# %%
plt.scatter(average_law_count_by_income_period.period, average_law_count_by_income_period.total_law_counts, linewidth=2, color='#a45c7c'),
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Average Law Count')
plt.title('Average Law Count over period')
plt.show()

# %%
average_law_count_by_region = (df_law_count.groupby(['Region'], as_index=False)['total_law_counts'].mean())
average_law_count_by_region

# %%
average_law_count_by_economy = (df_law_count.groupby(['economy'], as_index=False)['total_law_counts'].mean())
average_law_count_by_economy

# %%
average_law_count_by_economy = average_law_count_by_economy.sort_values(by = 'total_law_counts', ascending = False)
average_law_count_by_economy

# %%
average_law_count_by_economy.head(15)

# %%
average_law_count_by_economy.tail(15)

# %%
average_law_count_by_income_period = (df_law_count.groupby(['Income_group', 'period'], as_index=False)['total_law_counts'].mean())
average_law_count_by_income_period

# %%
df_average_High_income = average_law_count_by_income_period.loc[average_law_count_by_income_period['Income_group'] == 'High income']
df_average_High_income = df_average_High_income.sort_values(by = 'period', ascending = True)
df_average_High_income

# %%
df_average_High_income_mean = df_average_High_income['total_law_counts'].mean()
df_average_High_income_mean

# %%
df_average_High_income_median = df_average_High_income['total_law_counts'].median()
df_average_High_income_median

# %%
df_average_Low_income = average_law_count_by_income_period.loc[average_law_count_by_income_period['Income_group'] == 'Low income']
df_average_Low_income = df_average_Low_income.sort_values(by = 'period', ascending = True)
df_average_Low_income

# %%
df_average_Low_income_mean = df_average_Low_income['total_law_counts'].mean()
df_average_Low_income_mean

# %%
df_average_Low_income_median = df_average_Low_income['total_law_counts'].median()
df_average_Low_income_median

# %%
df_average_Lower_middle_income = average_law_count_by_income_period.loc[average_law_count_by_income_period['Income_group'] == 'Lower middle income']
df_average_Lower_middle_income = df_average_Lower_middle_income.sort_values(by = 'period', ascending = True)
df_average_Lower_middle_income

# %%
df_average_Lower_middle_income_mean = df_average_Lower_middle_income['total_law_counts'].mean()
df_average_Lower_middle_income_mean

# %%
df_average_Lower_middle_income_median = df_average_Lower_middle_income['total_law_counts'].median()
df_average_Lower_middle_income_median

# %%
df_average_Upper_middle_income = average_law_count_by_income_period.loc[average_law_count_by_income_period['Income_group'] == 'Upper middle income']
df_average_Upper_middle_income = df_average_Upper_middle_income.sort_values(by = 'period', ascending = True)
df_average_Upper_middle_income

# %%
df_average_Upper_middle_income_mean = df_average_Upper_middle_income['total_law_counts'].mean()
df_average_Upper_middle_income_mean

# %%
df_average_Upper_middle_income_median = df_average_Upper_middle_income['total_law_counts'].median()
df_average_Upper_middle_income_median

# %%
#labels = month_2020_df.Month
#calls_2019 = month_2019_df.number_calls
#calls_2020 = month_2020_df.number_calls

#x = np.arange(len(labels))  # the label locations
#width = 0.35  # the width of the bars
#fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/2, calls_2019, width, color='#a45c7c', label='2019')
#rects2 = ax.bar(x + width/2, calls_2020, width, color='#E97223', label='2020')
#plt.rcParams["figure.figsize"] = [15,10]


# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_ylabel('Call Volume')
#ax.set_title('2019 vs 2020 Call Volumes')
#ax.set_xticks(x)
#ax.set_xticklabels(labels)
#ax.legend()
#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)
#fig.tight_layout();

# %%
def period(counter):
    if (counter['reportyr'] == 1972) | (counter['reportyr'] <= 1976) :
        return '1972-1976'
    if (counter['reportyr'] == 1977) | (counter['reportyr'] <= 1981) :
        return '1977-1981'
    if (counter['reportyr'] == 1982) | (counter['reportyr'] <= 1986) :
        return '1982-1986'
    if (counter['reportyr'] == 1987) | (counter['reportyr'] <= 1991) :
        return '1987-1991'
    if (counter['reportyr'] == 1992) | (counter['reportyr'] <= 1996) :
        return '1992-1996'
    if (counter['reportyr'] == 1997) | (counter['reportyr'] <= 2001) :
        return '1997-2001'
    if (counter['reportyr'] == 2002) | (counter['reportyr'] <= 2006) :
        return '2002-2006'
    if (counter['reportyr'] == 2007) | (counter['reportyr'] <= 2011) :
        return '2007-2011'
    if (counter['reportyr'] == 2012) | (counter['reportyr'] <= 2016) :
        return '2012-2016'
    else:
        return '2017-2021'

df_entrepreneur["period"] = df_entrepreneur.apply(period, axis=1)

# %%
df_average_1972 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1972-1976']
df_average_1972 = df_average_1972.sort_values(by = 'total_law_counts', ascending = False)
df_average_1972

# %%
df_average_1977 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1977-1981']
df_average_1977 = df_average_1977.sort_values(by = 'total_law_counts', ascending = False)
df_average_1977

# %%
df_average_1982 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1982-1986']
df_average_1982 = df_average_1982.sort_values(by = 'total_law_counts', ascending = False)
df_average_1982

# %%
df_average_1987 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1987-1991']
df_average_1987 = df_average_1987.sort_values(by = 'total_law_counts', ascending = False)
df_average_1987

# %%
df_average_1992 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1992-1996']
df_average_1992 = df_average_1992.sort_values(by = 'total_law_counts', ascending = False)
df_average_1992

# %%
df_average_1997 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '1997-2001']
df_average_1997 = df_average_1997.sort_values(by = 'total_law_counts', ascending = False)
df_average_1997

# %%
df_average_2002 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2002-2006']
df_average_2002 = df_average_2002.sort_values(by = 'total_law_counts', ascending = False)
df_average_2002

# %%
df_average_2007 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2007-2011']
df_average_2007 = df_average_2007.sort_values(by = 'total_law_counts', ascending = False)
df_average_2007

# %%
df_average_2012 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2012-2016']
df_average_2012 = df_average_2012.sort_values(by = 'total_law_counts', ascending = False)
df_average_2012

# %%
df_average_2017 = average_law_count_by_income_period.loc[average_law_count_by_income_period['period'] == '2017-2021']
df_average_2017 = df_average_2017.sort_values(by = 'total_law_counts', ascending = False)
df_average_2017

# %%
fig, ((ax1, ax2, ax3, ax4, ax5), (ax6, ax7, ax8, ax9, ax10)) = plt.subplots(nrows = 2, ncols = 5, sharey=True, figsize=(15,15))
#fig.subplots_adjust(wspace=0.05)
#plt.figure(figsize=(25,45))
fig.suptitle('Average Law Counts in 1971-2021 by Income Group', fontsize=26)
ax1.set_title('1971-1975')
ax1.bar(df_average_1971.Income_group, df_average_1971.total_law_counts)#, color='green',edgecolor='black', label='28,501')
#ax1.set_xticks(range(1,31, 1))

ax2.bar(df_average_1976.Income_group, df_average_1976.total_law_counts)#, edgecolor='black', label='5,972,641')
ax2.set_title('1976-1980')
#ax2.axvline(x=25, color='g')


ax3.bar(df_average_1981.Income_group, df_average_1981.total_law_counts)
ax3.set_title('1981-1985')


ax4.bar(df_average_1986.Income_group, df_average_1986.total_law_counts)
ax4.set_title('1986-1990')


ax5.bar(df_average_1991.Income_group, df_average_1991.total_law_counts)
ax5.set_title('1991-1995')

ax6.bar(df_average_1996.Income_group, df_average_1996.total_law_counts)
ax6.set_title('1996-2000')


ax7.bar(df_average_2001.Income_group, df_average_2001.total_law_counts)
ax7.set_title('2001-2005')

ax8.bar(df_average_2006.Income_group, df_average_2006.total_law_counts)
ax8.set_title('2006-2010')
#ax8.axvline(x=7, color='red') # I added a vertical red bar here because they received the highest # of call -93-

ax9.bar(df_average_2011.Income_group, df_average_2011.total_law_counts)
ax9.set_title('2011-2015')

ax10.bar(df_average_2016.Income_group, df_average_2016.total_law_counts)
ax10.set_title('2016-2021')


#fig.text(0.48, -0.01, 'columns name', fontsize=20, ha='center')
#fig.text(0.04, 0.5, 'Count', va='center', rotation='vertical', fontsize=20)
#fig.legend(loc="upper left", fontsize=20)
#plt.axhline(y=350, linestyle='--', color='red', label = 'Weekday average')
#plt.axvline(x=38, color='red')
plt.yticks(fontsize=60)
plt.xticks(rotation = 90)
plt.show();

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, sharey=True, figsize=(15,15))
fig.subplots_adjust(wspace=0.05)
#plt.figure(figsize=(25,45))
fig.suptitle('Average Law Counts in 1971-2021 by Income Group', fontsize=26)
ax1.set_title('High income')
ax1.bar(df_average_High_income.period, df_average_High_income.total_law_counts), # color='green',edgecolor='black', label='28,501')
ax1.set_xticks(range(10))

ax2.bar(df_average_Upper_middle_income.period, df_average_Upper_middle_income.total_law_counts)#, edgecolor='black', label='5,972,641')
ax2.set_title('Upper middle income'),
ax2.set_xticks(range(10))
#ax2.axvline(x=25, color='g')


ax3.bar(df_average_Lower_middle_income.period, df_average_Lower_middle_income.total_law_counts)
ax3.set_title('Lower middle income'),
ax3.set_xticks(range(10))



ax4.bar(df_average_Low_income.period, df_average_Low_income.total_law_counts)
ax4.set_title('Low income'),
ax4.set_xticks(range(10))




#fig.text(0.48, -0.01, 'columns name', fontsize=20, ha='center')
#fig.text(0.04, 0.5, 'Count', va='center', rotation='vertical', fontsize=20)
#fig.legend(loc="upper left", fontsize=20)
plt.axhline(y=1, linestyle='--', color='red', label = '1')
plt.axhline(y=2, linestyle='--', color='red', label = '2')
plt.axhline(y=3, linestyle='--', color='red', label = '3')
plt.axhline(y=4, linestyle='--', color='red', label = '4')
#plt.axhline(y=3.1844444444444444, linestyle='--', color='red', label = 'average')
#plt.axhline(y=2, linestyle='--', color='red', label = 'average')
#plt.axvline(x=38, color='red')
plt.yticks(fontsize=60)
locs, labels = plt.xticks()
g.set_xticklabels(rotation=45)
#plt.setp(labels, rotation=45)
plt.show();

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=average_law_count_by_income_period, kind="bar",
    x="period", y="total_law_counts", hue="Income_group",
    ci="sd", palette="Paired", alpha=.6, height=10, legend=False)
g.despine(left=True)
g.set_axis_labels("", "Average Law Counts")
g.set_xticklabels(rotation=45)
#g.legend.set_title("Average Law Counts in 1971-2021 by Income Group")
#g.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %%
average_law_count_by_region_period = (df_law_count.groupby(['Region', 'period'], as_index=False)['total_law_counts'].mean())
average_law_count_by_region_period

# %%
count_law_count_by_region_period = (df_law_count.groupby(['total_law_counts'], as_index=False)['total_law_counts'].count())
count_law_count_by_region_period

# %%
region_law_count_value_count = average_law_count_by_region_period.Region.value_counts()
region_law_count_value_count

# %%
df_average_South_Asia  = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'South Asia']
df_average_South_Asia = df_average_South_Asia.sort_values(by = 'period', ascending = True)
df_average_South_Asia

# %%
df_average_South_Asia.info()

# %%
df_average_Sub_Saharan_Africa = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'Sub-Saharan Africa']
df_average_Sub_Saharan_Africa = df_average_Sub_Saharan_Africa.sort_values(by = 'period', ascending = True)
df_average_Sub_Saharan_Africa

# %%
df_average_High_income_OECD = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'High income: OECD']
df_average_High_income_OECD = df_average_High_income_OECD.sort_values(by = 'period', ascending = True)
df_average_High_income_OECD

# %%
df_average_High_income_OECD.info()

# %%
df_average_Europe_Central_Asia  = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'Europe & Central Asia']
df_average_Europe_Central_Asia = df_average_Europe_Central_Asia.sort_values(by = 'period', ascending = True)
df_average_Europe_Central_Asia

# %%
df_average_Latin_America_Caribbean = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'Latin America & Caribbean']
df_average_Latin_America_Caribbean = df_average_Latin_America_Caribbean.sort_values(by = 'period', ascending = True)
df_average_Latin_America_Caribbean

# %%
df_average_Middle_East_North_Africa = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'Middle East & North Africa']
df_average_Middle_East_North_Africa = df_average_Middle_East_North_Africa.sort_values(by = 'period', ascending = True)
df_average_Middle_East_North_Africa

# %%
df_average_Middle_East_North_Africa

# %%
df_average_Middle_East_North_Africa.info()

# %%
df_average_East_Asia_Pacific = average_law_count_by_region_period.loc[average_law_count_by_region_period['Region'] == 'East Asia & Pacific']
df_average_East_Asia_Pacific = df_average_East_Asia_Pacific.sort_values(by = 'period', ascending = True)
df_average_East_Asia_Pacific

# %%
df_average_East_Asia_Pacific

# %%
df_average_East_Asia_Pacific.info()

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(nrows = 4, ncols = 2, sharey=True, figsize=(40, 30))
#axis = axis.flatten()
fig.subplots_adjust(wspace=0.05)
#plt.figure(figsize=(25,45))
fig.suptitle('Average Law Counts in 1971-2021 by Region', fontsize=26)
ax1.set_title('South Asia')
ax1.bar(df_average_South_Asia.period, df_average_South_Asia.total_law_counts), # color='green',edgecolor='black', label='28,501')
ax1.set_xticks(range(10))

ax2.bar(df_average_Sub_Saharan_Africa.period, df_average_Sub_Saharan_Africa.total_law_counts)#, edgecolor='black', label='5,972,641')
ax2.set_title('Sub-Saharan Africa'),
ax2.set_xticks(range(10))
#ax2.axvline(x=25, color='g')


ax3.bar(df_average_High_income_OECD.period, df_average_High_income_OECD.total_law_counts)
ax3.set_title('High income: OECD'),
ax3.set_xticks(range(10))


ax4.bar(df_average_Europe_Central_Asia.period, df_average_Europe_Central_Asia.total_law_counts)
ax4.set_title('Europe & Central Asia'),
ax4.set_xticks(range(10))

ax5.bar(df_average_Latin_America_Caribbean.period, df_average_Latin_America_Caribbean.total_law_counts)
ax5.set_title('Latin America & Caribbean'),
ax5.set_xticks(range(10))

ax6.bar(df_average_Middle_East_North_Africa.period, df_average_Middle_East_North_Africa.total_law_counts)
ax6.set_title('Middle East & North Africa'),
ax6.set_xticks(range(10))

ax7.bar(df_average_East_Asia_Pacific.period, df_average_East_Asia_Pacific.total_law_counts)
ax7.set_title('East Asia & Pacific'),
ax7.set_xticks(range(10))


#fig.text(0.48, -0.01, 'columns name', fontsize=20, ha='center')
#fig.text(0.04, 0.5, 'Count', va='center', rotation='vertical', fontsize=20)
#fig.legend(loc="upper left", fontsize=20)
#plt.axhline(y=1, linestyle='--', color='red', label = 'average')
#plt.axhline(y=2, linestyle='--', color='red', label = 'average')
#plt.axhline(y=3, linestyle='--', color='red', label = 'average')
#plt.axhline(y=4, linestyle='--', color='red', label = 'average')
#plt.axhline(y=3.1844444444444444, linestyle='--', color='red', label = 'average')
#plt.axhline(y=2, linestyle='--', color='red', label = 'average')
#plt.axvline(x=38, color='red')
plt.yticks(fontsize=60)
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
#ax1.tick_params(axis='x', labelrotation=45)
#ax2.tick_params(axis='x', labelrotation=45)
#ax1.tick_params(labelrotation=45, axis = 'x')
plt.show();

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=average_law_count_by_region_period, kind="bar",
    x="period", y="total_law_counts", hue="Region",
    ci="sd", palette="Paired", alpha=.6, height=10, legend=False)
g.despine(left=True)
g.set_axis_labels("", "Average Law Counts")
g.set_xticklabels(rotation=45)
#g.legend.set_title("Average Law Counts in 1971-2021 by Region")
#g.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=average_law_count_by_region_period, kind="bar",
    x="Region", y="total_law_counts", hue="period",
    ci="sd", palette="Paired", alpha=.6, height=10, legend=False)
g.despine(left=True)
g.set_axis_labels("", "Average Law Counts")
g.set_xticklabels(rotation=45)

#g.legend.set_title("Average Law Counts in 1971-2021 by Region")
#g.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df_law_count, kind="bar",
    x="period", y="total_law_counts", hue="Region",
    ci="sd", palette="Paired", alpha=.6, height=10, legend=False)
g.despine(left=True)
g.set_axis_labels("", "Law Counts")
g.set_xticklabels(rotation=45)
#g.legend.set_title("Average Law Counts in 1971-2021 by Region")
#g.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);
