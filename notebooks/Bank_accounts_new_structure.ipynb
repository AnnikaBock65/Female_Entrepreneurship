# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
bank_account_new = pd.read_csv('../data/Bank_account_data_NEW.csv', engine='python')
bank_account_new.shape
# Out:
# (10, 13)

# %%
bank_account_new
# Out:
#           Country_Name Country_Code    Year  \
# 0          High income          HIC  2014.0
# 1          High income          HIC  2017.0
# 2           Low income          LIC  2014.0
# 3           Low income          LIC  2017.0
# 4  Lower middle income          LMC  2014.0
# 5  Lower middle income          LMC  2017.0
# 6  Upper middle income          UMC  2014.0
# 7  Upper middle income          UMC  2017.0
# 8                  NaN          NaN     NaN
# 9                  NaN          NaN     NaN
#
#    Borrowed from a financial institution, female (% age 15+)  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# ...

# %%
bank_account = bank_account_new.iloc[0:8,0:14]
bank_account
# Out:
#           Country_Name Country_Code    Year  \
# 0          High income          HIC  2014.0
# 1          High income          HIC  2017.0
# 2           Low income          LIC  2014.0
# 3           Low income          LIC  2017.0
# 4  Lower middle income          LMC  2014.0
# 5  Lower middle income          LMC  2017.0
# 6  Upper middle income          UMC  2014.0
# 7  Upper middle income          UMC  2017.0
#
#    Borrowed from a financial institution, female (% age 15+)  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
#    Borrowed from a financial institution, male (% age 15+)  \
# ...

# %%
bank_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 13 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Country_Name                                                                  8 non-null      object
#  1   Country_Code                                                                  8 non-null      object
#  2   Year                                                                          8 non-null      float64
#  3   Borrowed from a financial institution, female (% age 15+)                     8 non-null      float64
#  4   Borrowed from a financial institution, male (% age 15+)                       8 non-null      float64
#  5   Borrowed from family or friends, male  (% age 15+)                            8 non-null      float64
# ...

# %%
bank_account['Year'].apply(np.floor)
# Out:
# 0    2014.0
# 1    2017.0
# 2    2014.0
# 3    2017.0
# 4    2014.0
# 5    2017.0
# 6    2014.0
# 7    2017.0
# Name: Year, dtype: float64

# %%
bank_account['Year'] = bank_account['Year'].astype(int)

# %%
bank_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 13 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Country_Name                                                                  8 non-null      object
#  1   Country_Code                                                                  8 non-null      object
#  2   Year                                                                          8 non-null      int32
#  3   Borrowed from a financial institution, female (% age 15+)                     8 non-null      float64
#  4   Borrowed from a financial institution, male (% age 15+)                       8 non-null      float64
#  5   Borrowed from family or friends, male  (% age 15+)                            8 non-null      float64
# ...

# %%
bank_account
# Out:
#           Country_Name Country_Code  Year  \
# 0          High income          HIC  2014
# 1          High income          HIC  2017
# 2           Low income          LIC  2014
# 3           Low income          LIC  2017
# 4  Lower middle income          LMC  2014
# 5  Lower middle income          LMC  2017
# 6  Upper middle income          UMC  2014
# 7  Upper middle income          UMC  2017
#
#    Borrowed from a financial institution, female (% age 15+)  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
#    Borrowed from a financial institution, male (% age 15+)  \
# ...

# %%
bank_account_renamed = bank_account.rename(columns = {'Country_Name': 'Income_group', 'Country_Code': 'Income_group_Code', 'Borrowed from a financial institution, female (% age 15+)':'Borrowed_from_a_financial_institution_female_pct_age_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed from a financial institution, male (% age 15+)':'Borrowed_from_a_financial_institution_male_pct_age_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed from family or friends, male (% age 15+)':'Borrowed_from_family_or_friends_male_pct_age_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed from family or friends, female (% age 15+)':'Borrowed_from_family_or_friends_female_pct_age_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed from family or friends, male (% age 15+)':'Borrowed_ffriends_male_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed to start, operate, or expand a farm or business, female (% age 15+)':'Borrowed_business_female_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed to start, operate, or expand a farm or business, male (% age 15+)':'Borrowed_business_male_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Financial institution account,male(% age 15+)':'Financial_institution_account_male_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Financial institution account,female(% age 15+)':'Financial_institution_account_female_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Saved to start, operate, or expand a farm or business, female (% age 15+)':'Saved_business_female_pct_age_o_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Saved to start, operate, or expand a farm or business, male (% age 15+)':'Saved_business_male_pct_age_o_15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 13 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Income_group                                             8 non-null      object
#  1   Income_group_Code                                        8 non-null      object
#  2   Year                                                     8 non-null      int32
#  3   Borrowed_from_a_financial_institution_female_pct_age_15  8 non-null      float64
#  4   Borrowed_from_a_financial_institution_male_pct_age_15    8 non-null      float64
#  5   Borrowed from family or friends, male  (% age 15+)       8 non-null      float64
#  6   Borrowed_from_family_or_friends_female_pct_age_15        8 non-null      float64
#  7   Borrowed_business_female_pct_age_o15                     8 non-null      float64
# ...

# %%
bank_account_renamed = bank_account_renamed.rename(columns = {'Borrowed from family or friends, male  (% age 15+)':'Borrowed_ffriends_male_pct_age_o15'})

# %%
bank_account_renamed
# Out:
#           Income_group Income_group_Code  Year  \
# 0          High income               HIC  2014
# 1          High income               HIC  2017
# 2           Low income               LIC  2014
# 3           Low income               LIC  2017
# 4  Lower middle income               LMC  2014
# 5  Lower middle income               LMC  2017
# 6  Upper middle income               UMC  2014
# 7  Upper middle income               UMC  2017
#
#    Borrowed_from_a_financial_institution_female_pct_age_15  \
# 0                                          15.638198
# 1                                          16.744610
# 2                                           5.185501
# 3                                           6.411187
# 4                                           7.077247
# 5                                           7.314330
# 6                                          10.118506
# 7                                           8.504173
#
# ...

# %%
bank_account_renamed.to_csv('bank_accounts_14_18_renamed_restruc.csv')

# %%
borrowed_business_over_income  = (bank_account_renamed.groupby(['Income_group'], as_index=False)['Borrowed_business_female_pct_age_o15'].mean())
borrowed_business_over_income
# Out:
#           Income_group  Borrowed_business_female_pct_age_o15
# 0          High income                              1.796355
# 1           Low income                             11.249970
# 2  Lower middle income                              6.900915
# 3  Upper middle income                              4.764572
