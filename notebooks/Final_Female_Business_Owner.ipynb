# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
female_business_owner = pd.read_csv('../data/female_business_owner_data.csv', engine='python')
female_business_owner.shape
# Out:
# (379, 18)

# %%
female_business_owner.head()
# Out:
#        Country Income group    Year  \
# 0  Afghanistan   Low income  2014.0
# 1  Afghanistan   Low income  2015.0
# 2  Afghanistan   Low income  2016.0
# 3  Afghanistan   Low income  2017.0
# 4  Afghanistan   Low income  2018.0
#
#   Number of female business owners of new LLCs  \
# 0                                           65
# 1                                           45
# 2                                           65
# 3                                           88
# 4                                          177
#
#   Number of male business owners of new LLCs  \
# 0                                      5,043
# 1                                      4,704
# 2                                      5,036
# 3                                      6,047
# 4                                      8,482
#
#   Total number of business owners of new LLCs  \
# 0                                       5,108
# 1                                       4,749
# ...

# %%
female_business_owner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       365 non-null    object
#  1   Income group                                  365 non-null    object
#  2   Year                                          365 non-null    float64
#  3   Number of female business owners of new LLCs  250 non-null    object
#  4   Number of male business owners of new LLCs    250 non-null    object
#  5   Total number of business owners of new LLCs   250 non-null    object
#  6   Number of female sole proprietors             249 non-null    object
#  7   Number of male sole proprietors               249 non-null    object
#  8   Total number of sole proprietors              249 non-null    object
# ...

# %%
female_business_owner.isnull().sum()
# Out:
# Country                                          14
# Income group                                     14
# Year                                             14
# Number of female business owners of new LLCs    129
# Number of male business owners of new LLCs      129
# Total number of business owners of new LLCs     129
# Number of female sole proprietors               130
# Number of male sole proprietors                 130
# Total number of sole proprietors                130
# Number of female directors of new LCCS          177
# Number of male directors of new LCCS            177
# Total number of directors of new LCCS           177
# Share of female business owners of new LLCs     129
# Share of male business owners of new LLCs       129
# Share of female sole proprietors                130
# Share of male sole proprietors                  130
# Share of female directors of new LCCs           200
# Share of male directors of new LCCs             200
# dtype: int64

# %%
female_business_owner_drop = female_business_owner.dropna()

# %%
female_business_owner_drop.isnull().sum()
# Out:
# Country                                         0
# Income group                                    0
# Year                                            0
# Number of female business owners of new LLCs    0
# Number of male business owners of new LLCs      0
# Total number of business owners of new LLCs     0
# Number of female sole proprietors               0
# Number of male sole proprietors                 0
# Total number of sole proprietors                0
# Number of female directors of new LCCS          0
# Number of male directors of new LCCS            0
# Total number of directors of new LCCS           0
# Share of female business owners of new LLCs     0
# Share of male business owners of new LLCs       0
# Share of female sole proprietors                0
# Share of male sole proprietors                  0
# Share of female directors of new LCCs           0
# Share of male directors of new LCCs             0
# dtype: int64

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop.tail()
# Out:
#     Country         Income group    Year  \
# 360  Zambia  Lower middle income  2014.0
# 361  Zambia  Lower middle income  2015.0
# 362  Zambia  Lower middle income  2016.0
# 363  Zambia  Lower middle income  2017.0
# 364  Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 360                                        4,611
# 361                                        4,627
# 362                                        4,041
# 363                                        4,059
# 364                                        4,481
#
#     Number of male business owners of new LLCs  \
# 360                                     17,184
# 361                                     15,545
# 362                                     13,905
# 363                                     14,931
# 364                                     16,092
#
#     Total number of business owners of new LLCs  \
# 360                                      21,795
# ...

# %%
female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].str.replace('%', '')
# Out:
# <ipython-input-10-9ed9873abcb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].str.replace('%', '')
# Out:
# <ipython-input-11-e4411c152b59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-12-21bbfdc729c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-13-6f60126ae5f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].str.replace('%', '')
# Out:
# <ipython-input-14-69278af0122d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].str.replace('%', '')
# Out:
# <ipython-input-15-0122408e40c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].str.replace('%', '')

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    float64
#  3   Number of female business owners of new LLCs  139 non-null    object
#  4   Number of male business owners of new LLCs    139 non-null    object
#  5   Total number of business owners of new LLCs   139 non-null    object
#  6   Number of female sole proprietors             139 non-null    object
#  7   Number of male sole proprietors               139 non-null    object
#  8   Total number of sole proprietors              139 non-null    object
# ...

# %%
female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].astype(float)
# Out:
# <ipython-input-18-543dc57ac27a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].astype(float)

# %%
female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].astype(float)
# Out:
# <ipython-input-19-2981b4115821>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].astype(float)

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)
# Out:
# <ipython-input-20-2ef0581b24e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)
# Out:
# <ipython-input-21-d20f7bc39483>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].astype(float)
# Out:
# <ipython-input-22-220c018adb67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].astype(float)

# %%
female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].astype(float)
# Out:
# <ipython-input-23-787f0f162b30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].astype(float)

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].str.replace(',', '')
# Out:
# <ipython-input-26-9ae5ebb32d0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].str.replace(',', '')

# %%
female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].astype(int)
# Out:
# <ipython-input-27-c3b5de7c14fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].astype(int)

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].str.replace(',', '')
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].str.replace(',', '')
female_business_owner_drop['Total number of business owners of new LLCs'] = female_business_owner_drop['Total number of business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of male business owners of new LLCs'] = female_business_owner_drop['Number of male business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of female directors of new LCCS'] = female_business_owner_drop['Number of female directors of new LCCS'].str.replace(',', '')
# Out:
# <ipython-input-29-b39d00e3635c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].str.replace(',', '')
# <ipython-input-29-b39d00e3635c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Number of female directors of new LCCS'] = female_business_owner_drop['Number of female directors of new LCCS'].astype(int)
# Out:
# <ipython-input-31-bcfac6e872e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].astype(int)
# <ipython-input-31-bcfac6e872e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    float64
#  3   Number of female business owners of new LLCs  139 non-null    object
#  4   Number of male business owners of new LLCs    139 non-null    object
#  5   Total number of business owners of new LLCs   139 non-null    object
#  6   Number of female sole proprietors             139 non-null    object
#  7   Number of male sole proprietors               139 non-null    int32
#  8   Total number of sole proprietors              139 non-null    int32
# ...

# %%
female_business_owner_drop['Number of female business owners of new LLCs'] = female_business_owner_drop['Number of female business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of male business owners of new LLCs'] = female_business_owner_drop['Number of male business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Total number of business owners of new LLCs'] = female_business_owner_drop['Total number of business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of female sole proprietors'] = female_business_owner_drop['Number of female sole proprietors'].str.replace(',', '')
# Out:
# <ipython-input-33-ccc307a5a1d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of female business owners of new LLCs'] = female_business_owner_drop['Number of female business owners of new LLCs'].str.replace(',', '')
# <ipython-input-33-ccc307a5a1d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
female_business_owner_drop['Number of female business owners of new LLCs'] = female_business_owner_drop['Number of female business owners of new LLCs'].astype(int)
female_business_owner_drop['Number of male business owners of new LLCs'] = female_business_owner_drop['Number of male business owners of new LLCs'].astype(int)
female_business_owner_drop['Total number of business owners of new LLCs'] = female_business_owner_drop['Total number of business owners of new LLCs'].astype(int)
female_business_owner_drop['Number of female sole proprietors'] = female_business_owner_drop['Number of female sole proprietors'].astype(int)
# Out:
# <ipython-input-34-c2256c299304>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of female business owners of new LLCs'] = female_business_owner_drop['Number of female business owners of new LLCs'].astype(int)
# <ipython-input-34-c2256c299304>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male business owners of new LLCs'] = female_business_owner_drop['Number of male business owners of new LLCs'].astype(int)
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#      Number of female business owners of new LLCs  \
# 0                                              65
# 1                                              45
# 2                                              65
# 3                                              88
# 4                                             177
# ..                                            ...
# 360                                          4611
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    float64
#  3   Number of female business owners of new LLCs  139 non-null    int32
#  4   Number of male business owners of new LLCs    139 non-null    int32
#  5   Total number of business owners of new LLCs   139 non-null    int32
#  6   Number of female sole proprietors             139 non-null    int32
#  7   Number of male sole proprietors               139 non-null    int32
#  8   Total number of sole proprietors              139 non-null    int32
# ...

# %%
female_business_owner_drop['Year'].apply(np.floor)
# Out:
# 0      2014.0
# 1      2015.0
# 2      2016.0
# 3      2017.0
# 4      2018.0
#         ...
# 360    2014.0
# 361    2015.0
# 362    2016.0
# 363    2017.0
# 364    2018.0
# Name: Year, Length: 139, dtype: float64

# %%
female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)
# Out:
# <ipython-input-38-58c5345046ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    int32
#  3   Number of female business owners of new LLCs  139 non-null    int32
#  4   Number of male business owners of new LLCs    139 non-null    int32
#  5   Total number of business owners of new LLCs   139 non-null    int32
#  6   Number of female sole proprietors             139 non-null    int32
#  7   Number of male sole proprietors               139 non-null    int32
#  8   Total number of sole proprietors              139 non-null    int32
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#      Number of female business owners of new LLCs  \
# 0                                              65
# 1                                              45
# 2                                              65
# 3                                              88
# 4                                             177
# ..                                            ...
# 360                                          4611
# ...

# %%
female_business_owner_drop_renamed = female_business_owner_drop.rename(columns = {'Income group': 'Income_group', 'Number of female business owners of new LLCs': 'Number_of_female_business_owners_of_new_LLCs', 'Number of male business owners of new LLCs':'Number_of_male_business_owners_of_new_LLCs','Total number of business owners of new LLCs':'Total_number_of_business_owners_of_new_LLCs', 'Number of female sole proprietors':'Number_of_female_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Number of male sole proprietors': 'Number_of_male_sole_proprietors', 'Number of female business owners of new LLCs': 'Number_of_female_business_owners_of_new_LLCs', 'Number of male business owners of new LLCs':'Number_of_male_business_owners_of_new_LLCs','Total number of sole proprietors':'Total_number_of_sole_proprietors', 'Number of female directors of new LCCS':'Number_of_female_directors_of_new_LCCS'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Total number of business owners of new LLCs': 'Total_number_of_business_owners_of_new_LLCs', 'Number of female business owners of new LLCs': 'Number_of_female_business_owners_of_new_LLCs', 'Number of male business owners of new LLCs':'Number_of_male_business_owners_of_new_LLCs','Total number of business owners of new LLCs':'Total_number_of_business_owners_of_new_LLCs', 'Number of female sole proprietors':'Number_of_female_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Number of male directors of new LCCS':'Number_of_male_directors_of_new_LCCS', 'Number of male sole proprietors':'Number_of_male_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Total number of directors of new LCCS':'Total_number_of_directors_of_new_LCCS', 'Share of female business owners of new LLCs':'Share_of_female_business_owners_of_new_LLCs' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male business owners of new LLCs':'Share_of_male_business_owners_of_new_LLCs' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of female sole proprietors':'Share_of_female_sole_proprietors' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male sole proprietors':'Share_of_male_sole_proprietors' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of female directors of new LCCs':'Share_of_female_directors_of_new_LCCs' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male directors of new LCCs':'Share_of_male_directors_of_new_LCCs' })

# %%
female_business_owner_drop_renamed
# Out:
#          Country         Income_group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#      Number_of_female_business_owners_of_new_LLCs  \
# 0                                              65
# 1                                              45
# 2                                              65
# 3                                              88
# 4                                             177
# ..                                            ...
# 360                                          4611
# ...

# %%
female_business_owner_drop.to_csv('female_business_owner_prep.csv')

# %%
female_business_owner_drop_renamed.to_csv('female_business_owner_renamed.csv')

# %%
fem_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_business_owners_of_new_LLCs'].mean())
fem_LLCs_income
# Out:
#           Income_group  Number_of_female_business_owners_of_new_LLCs
# 0          High income                                   3876.250000
# 1           Low income                                   1027.066667
# 2  Lower middle income                                  29368.960000
# 3  Upper middle income                                   8179.018182

# %%
fem_sole_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_sole_proprietors'].mean())
fem_sole_income
# Out:
#           Income_group  Number_of_female_sole_proprietors
# 0          High income                        4024.000000
# 1           Low income                        5731.666667
# 2  Lower middle income                       11952.520000
# 3  Upper middle income                       21919.145455

# %%
fem_directors_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_directors_of_new_LCCS'].mean())
fem_directors_income
# Out:
#           Income_group  Number_of_female_directors_of_new_LCCS
# 0          High income                             2765.409091
# 1           Low income                              365.866667
# 2  Lower middle income                            14016.160000
# 3  Upper middle income                             4516.800000

# %%
High_income_average = fem_directors_income.query('Income_group == "High income"')
High_income_average
# Out:
#   Income_group  Number_of_female_directors_of_new_LCCS
# 0  High income                             2765.409091

# %%
High_income_average.round(0)
High_income_average['Number_of_female_directors_of_new_LCCS'] = High_income_average['Number_of_female_directors_of_new_LCCS'].astype(int)
# Out:
# <ipython-input-58-5bcb96df1356>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   High_income_average['Number_of_female_directors_of_new_LCCS'] = High_income_average['Number_of_female_directors_of_new_LCCS'].astype(int)

# %%
High_income_average.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Income_group                            1 non-null      object
#  1   Number_of_female_directors_of_new_LCCS  1 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 20.0+ bytes

# %%
High_income_average
# Out:
#   Income_group  Number_of_female_directors_of_new_LCCS
# 0  High income                                    2765

# %%
female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)
# Out:
# <ipython-input-61-58c5345046ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)

# %%
High_income_average.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Income_group                            1 non-null      object
#  1   Number_of_female_directors_of_new_LCCS  1 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 20.0+ bytes

# %%
High_income_sub = female_business_owner_drop_renamed.query('Income_group == "High income"')
High_income_sub.head(2)
# Out:
#     Country Income_group  Year  Number_of_female_business_owners_of_new_LLCs  \
# 75  Denmark  High income  2014                                          3715
# 76  Denmark  High income  2015                                          5423
#
#     Number_of_male_business_owners_of_new_LLCs  \
# 75                                       16556
# 76                                       21724
#
#     Total_number_of_business_owners_of_new_LLCs  \
# 75                                        20271
# 76                                        27147
#
#     Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 75                              11369                            20919
# 76                              13240                            22204
#
#     Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LCCS  \
# 75                             32288                                    1055
# ...

# %%
High_income_sub['difference_to_average_directors'] = High_income_sub['Number_of_female_directors_of_new_LCCS'] - High_income_average['Number_of_female_directors_of_new_LCCS']
# Out:
# <ipython-input-64-e2cad04447b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   High_income_sub['difference_to_average_directors'] = High_income_sub['Number_of_female_directors_of_new_LCCS'] - High_income_average['Number_of_female_directors_of_new_LCCS']

# %%
High_income_sub['difference_to_average_directors']  = High_income_sub['difference_to_average_directors'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-dce237369dab> in <module>
# ----> 1 High_income_sub['difference_to_average_directors']  = High_income_sub['difference_to_average_directors'].astype(int)
#
# ~\anaconda64\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda64\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
# ...

# %%
High_income_sub
# Out:
#            Country Income_group  Year  \
# 75         Denmark  High income  2014
# 76         Denmark  High income  2015
# 77         Denmark  High income  2016
# 78         Denmark  High income  2017
# 79         Denmark  High income  2018
# 85         Estonia  High income  2014
# 86         Estonia  High income  2015
# 87         Estonia  High income  2016
# 88         Estonia  High income  2017
# 89         Estonia  High income  2018
# 155         Latvia  High income  2014
# 156         Latvia  High income  2015
# 157         Latvia  High income  2016
# 158         Latvia  High income  2017
# 159         Latvia  High income  2018
# 185          Malta  High income  2014
# 186          Malta  High income  2015
# 187          Malta  High income  2016
# 188          Malta  High income  2017
# 189          Malta  High income  2018
# 236         Norway  High income  2015
# 237         Norway  High income  2016
# 238         Norway  High income  2017
# ...

# %%
High_income_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 75 to 329
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       44 non-null     object
#  1   Income_group                                  44 non-null     object
#  2   Year                                          44 non-null     int32
#  3   Number_of_female_business_owners_of_new_LLCs  44 non-null     int32
#  4   Number_of_male_business_owners_of_new_LLCs    44 non-null     int32
#  5   Total_number_of_business_owners_of_new_LLCs   44 non-null     int32
#  6   Number_of_female_sole_proprietors             44 non-null     int32
#  7   Number_of_male_sole_proprietors               44 non-null     int32
#  8   Total_number_of_sole_proprietors              44 non-null     int32
# ...

# %%
Low_income_sub = female_business_owner_drop_renamed.query('Income_group == "Low income"')
Low_income_sub.head(2)
# Out:
#        Country Income_group  Year  \
# 0  Afghanistan   Low income  2014
# 1  Afghanistan   Low income  2015
#
#    Number_of_female_business_owners_of_new_LLCs  \
# 0                                            65
# 1                                            45
#
#    Number_of_male_business_owners_of_new_LLCs  \
# 0                                        5043
# 1                                        4704
#
#    Total_number_of_business_owners_of_new_LLCs  \
# 0                                         5108
# 1                                         4749
#
#    Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 0                                 14                             2117
# 1                                 26                             3110
#
#    Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LCCS  \
# 0                              2131                                      34
# ...

# %%
Lower_middle_income_sub = female_business_owner_drop_renamed.query('Income_group == "Lower middle income"')
Lower_middle_income_sub.head(2)
# Out:
#           Country         Income_group  Year  \
# 65  Cote d'Ivoire  Lower middle income  2014
# 66  Cote d'Ivoire  Lower middle income  2015
#
#     Number_of_female_business_owners_of_new_LLCs  \
# 65                                          1525
# 66                                          1181
#
#     Number_of_male_business_owners_of_new_LLCs  \
# 65                                        6509
# 66                                        5595
#
#     Total_number_of_business_owners_of_new_LLCs  \
# 65                                         8034
# 66                                         6776
#
#     Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 65                                678                             1840
# 66                                894                             2443
#
#     Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LCCS  \
# 65                              2518                                     678
# ...

# %%
Upper_middle_income_sub = female_business_owner_drop_renamed.query('Income_group == "Upper middle income"')
Upper_middle_income_sub.head(2)
# Out:
#    Country         Income_group  Year  \
# 5  Albania  Upper middle income  2014
# 6  Albania  Upper middle income  2015
#
#    Number_of_female_business_owners_of_new_LLCs  \
# 5                                           401
# 6                                           457
#
#    Number_of_male_business_owners_of_new_LLCs  \
# 5                                        1818
# 6                                        2159
#
#    Total_number_of_business_owners_of_new_LLCs  \
# 5                                         2219
# 6                                         2616
#
#    Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 5                               4984                             8812
# 6                              13317                            23649
#
#    Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LCCS  \
# 5                             13796                                     344
# ...

# %%
fem_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group', 'Year'], as_index=False)['Number_of_female_business_owners_of_new_LLCs'].mean())
fem_LLCs_income_year.head(2)
# Out:
#   Income_group  Year  Number_of_female_business_owners_of_new_LLCs
# 0  High income  2014                                   3271.750000
# 1  High income  2015                                   3427.666667

# %%
male_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_male_business_owners_of_new_LLCs'].mean())
male_LLCs_income
# Out:
#           Income_group  Number_of_male_business_owners_of_new_LLCs
# 0          High income                                11594.977273
# 1           Low income                                 7801.733333
# 2  Lower middle income                                62733.800000
# 3  Upper middle income                                17967.072727

# %%
male_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group','Year'], as_index=False)['Number_of_male_business_owners_of_new_LLCs'].mean())
male_LLCs_income_year
# Out:
#            Income_group  Year  Number_of_male_business_owners_of_new_LLCs
# 0           High income  2014                                 8799.875000
# 1           High income  2015                                10032.111111
# 2           High income  2016                                12287.888889
# 3           High income  2017                                13168.888889
# 4           High income  2018                                13375.555556
# 5            Low income  2014                                 6158.666667
# 6            Low income  2015                                 6045.666667
# 7            Low income  2016                                 7538.333333
# 8            Low income  2017                                 8488.666667
# 9            Low income  2018                                10777.333333
# 10  Lower middle income  2014                                 8995.750000
# 11  Lower middle income  2015                                66312.400000
# ...

# %%
total_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Total_number_of_business_owners_of_new_LLCs'].mean())
total_LLCs_income
# Out:
#           Income_group  Total_number_of_business_owners_of_new_LLCs
# 0          High income                                 15471.227273
# 1           Low income                                  8828.800000
# 2  Lower middle income                                 92102.760000
# 3  Upper middle income                                 26146.090909

# %%
total_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group','Year'], as_index=False)['Total_number_of_business_owners_of_new_LLCs'].mean())
total_LLCs_income_year
# Out:
#            Income_group  Year  Total_number_of_business_owners_of_new_LLCs
# 0           High income  2014                                 12071.625000
# 1           High income  2015                                 13459.777778
# 2           High income  2016                                 16337.444444
# 3           High income  2017                                 17456.777778
# 4           High income  2018                                 17652.777778
# 5            Low income  2014                                  6893.666667
# 6            Low income  2015                                  6891.000000
# 7            Low income  2016                                  8603.000000
# 8            Low income  2017                                  9634.333333
# 9            Low income  2018                                 12122.000000
# 10  Lower middle income  2014                                 11969.500000
# ...

# %%
female_business_owner_drop_renamed.Country.value_counts()
# Out:
# Albania            5
# Latvia             5
# Nepal              5
# Malta              5
# Lao PDR            5
# Georgia            5
# Cote d'Ivoire      5
# Oman               5
# Mauritius          5
# Tajikistan         5
# North Macedonia    5
# Serbia             5
# Qatar              5
# Estonia            5
# Jamaica            5
# Taiwan, China      5
# Belarus            5
# Zambia             5
# Romania            5
# Afghanistan        5
# Azerbaijan         5
# Slovenia           5
# Denmark            5
# Mongolia           5
# Algeria            5
# Malaysia           5
# Norway             4
# Nigeria            4
# Morocco            1
# Name: Country, dtype: int64

# %%
female_business_owner_drop_renamed.Income_group.value_counts()
# Out:
# Upper middle income    55
# High income            44
# Lower middle income    25
# Low income             15
# Name: Income_group, dtype: int64
