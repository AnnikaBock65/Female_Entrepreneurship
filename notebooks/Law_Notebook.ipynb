# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_law = pd.read_csv('../data/woman_law.csv', engine='python')
df_law.shape
# Out:
# (9690, 55)

# %%
df_law.head()
# Out:
#         ID      economy wbcodev2      Region Income group  reportyr  \
# 0  AFG1971  Afghanistan      AFG  South Asia   Low income      1971
# 1  AFG1972  Afghanistan      AFG  South Asia   Low income      1972
# 2  AFG1973  Afghanistan      AFG  South Asia   Low income      1973
# 3  AFG1974  Afghanistan      AFG  South Asia   Low income      1974
# 4  AFG1975  Afghanistan      AFG  South Asia   Low income      1975
#
#    WBL INDEX  MOBILITY  \
# 0       26.3        25
# 1       26.3        25
# 2       26.3        25
# 3       26.3        25
# 4       26.3        25
#
#   Can a woman apply for a passport in the same way as a man?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Can a woman travel outside the country in the same way as a man?  ...  \
# ...

# %%
df_law.tail()
# Out:
#            ID   economy wbcodev2              Region         Income group  \
# 9685  ZWE2017  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  MOBILITY  \
# 9685      2017       86.9       100
# 9686      2018       86.9       100
# 9687      2019       86.9       100
# 9688      2020       86.9       100
# 9689      2021       86.9       100
#
#      Can a woman apply for a passport in the same way as a man?  \
# 9685                                                Yes
# 9686                                                Yes
# 9687                                                Yes
# 9688                                                Yes
# ...

# %%
df_law.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 55 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   ID                                                                                      9690 non-null   object
#  1   economy                                                                                 9690 non-null   object
#  2   wbcodev2                                                                                9690 non-null   object
#  3   Region                                                                                  9690 non-null   object
#  4   Income group                                                                            9690 non-null   object
# ...

# %%
df_law.isnull().sum()
# Out:
# ID                                                                                        0
# economy                                                                                   0
# wbcodev2                                                                                  0
# Region                                                                                    0
# Income group                                                                              0
# reportyr                                                                                  0
# WBL INDEX                                                                                 0
# MOBILITY                                                                                  0
# Can a woman apply for a passport in the same way as a man?                                0
# Can a woman travel outside the country in the same way as a man?                          0
# ...

# %%
df_law.describe()
# Out:
#           reportyr    WBL INDEX     MOBILITY    WORKPLACE          PAY  \
# count  9690.000000  9690.000000  9690.000000  9690.000000  9690.000000
# mean   1996.000000    59.425531    82.185243    41.707946    46.473168
# std      14.720361    18.219420    25.836910    32.858820    31.079331
# min    1971.000000    17.500000     0.000000     0.000000     0.000000
# 25%    1983.000000    46.900000    75.000000    25.000000    25.000000
# 50%    1996.000000    59.400000   100.000000    25.000000    50.000000
# 75%    2009.000000    71.900000   100.000000    50.000000    75.000000
# max    2021.000000   100.000000   100.000000   100.000000   100.000000
#
#           MARRIAGE   PARENTHOOD  Length of paid maternity leave  \
# count  9690.000000  9690.000000                     9690.000000
# mean     62.274510    34.257998                       84.412281
# std      29.605501    30.030973                       61.883196
# min       0.000000     0.000000                        0.000000
# ...

# %%
df_entre=df_law.drop(columns = ['MOBILITY', 'WORKPLACE', 'MARRIAGE', 'PARENTHOOD'])

# %%
df_entre
# Out:
#            ID      economy wbcodev2              Region         Income group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  \
# ...

# %%
df_entre=df_entre.drop(columns = ['Can a woman apply for a passport in the same way as a man?', 'Can a woman travel outside the country in the same way as a man?', 'Can a woman travel outside her home in the same way as a man?', 'Does the law grant spouses equal administrative authority over assets during marriage?'])

# %%
df_entre
# Out:
#            ID      economy wbcodev2              Region         Income group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  \
# ...

# %%
df_entre=df_entre.drop(columns = ['Can a woman choose where to live in the same way as a man?', 'Do male and female surviving spouses have equal rights to inherit assets?', 'Do sons and daughters have equal rights to inherit assets from their parents?'])

# %%
df_entre
# Out:
#            ID      economy wbcodev2              Region         Income group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_entre=df_entre.drop(columns = ['Are periods of absence due to childcare accounted for in pension benefits?', 'Is the mandatory retirement age for men and women the same?', 'Is the age at which men and women can retire with partial pension benefits the same?', 'Is the age at which men and women can retire with full pension benefits the same?'])

# %%
df_entre
# Out:
#            ID      economy wbcodev2              Region         Income group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_entre=df_entre.drop(columns = ['Does the law provide for the valuation of nonmonetary contributions?', 'PENSION', 'ASSETS', 'Is dismissal of pregnant workers prohibited?', 'Is there legislation on sexual harassment in employment?'])

# %%
df_entre
# Out:
#            ID      economy wbcodev2              Region         Income group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_entre.columns
# Out:
# Index(['ID', 'economy', 'wbcodev2', 'Region', 'Income group', 'reportyr',
#        'WBL INDEX', 'Can a woman get a job in the same way as a man?',
#        'Does the law prohibit discrimination in employment based on gender?',
#        'Are there criminal penalties or civil remedies for sexual harassment in employment?',
#        'PAY',
#        'Does the law mandate equal remuneration for work of equal value?',
#        'Can a woman work at night in the same way as a man?',
#        'Can a woman work in a job deemed dangerous in the same way as a man?',
#        'Can a woman work in an industrial job in the same way as a man?',
#        'Is there no legal provision that requires a married woman to obey her husband?',
#        'Can a woman be head of household in the same way as a man?',
#        'Is there legislation specifically addressing domestic violence?',
#        'Can a woman obtain a judgment of divorce in the same way as a man?',
# ...

# %%
df_entre=df_entre.drop(columns = ['Can a woman get a job in the same way as a man?', 'Does the law prohibit discrimination in employment based on gender?', 'Are there criminal penalties or civil remedies for sexual harassment in employment?', 'PAY', 'Does the law mandate equal remuneration for work of equal value?', 'Can a woman work at night in the same way as a man?', 'Can a woman work in a job deemed dangerous in the same way as a man?','Can a woman work in an industrial job in the same way as a man?','Is there no legal provision that requires a married woman to obey her husband?','Can a woman be head of household in the same way as a man?','Is there legislation specifically addressing domestic violence?','Can a woman obtain a judgment of divorce in the same way as a man?', 'Do men and women have equal ownership rights to immovable property?'])

# %%
df_entre.columns
# Out:
# Index(['ID', 'economy', 'wbcodev2', 'Region', 'Income group', 'reportyr',
#        'WBL INDEX', 'Does a woman have the same rights to remarry as a man?',
#        'Is paid leave of at least 14 weeks available to mothers?',
#        'Length of paid maternity leave',
#        'Does the government administer 100% of maternity leave benefits?',
#        'Is there paid leave available to fathers?',
#        'Length of paid paternity leave', 'Is there paid parental leave?',
#        'Shared days', 'Days for the mother', 'Days for the father',
#        'ENTREPRENEURSHIP',
#        'Can a woman sign a contract in the same way as a man?',
#        'Can a woman register a business in the same way as a man?',
#        'Can a woman open a bank account in the same way as a man?',
#        'Does the law prohibit discrimination in access to credit based on gender?'],
#       dtype='object')

# %%
df_entre=df_entre.drop(columns = ['Does a woman have the same rights to remarry as a man?','Is paid leave of at least 14 weeks available to mothers?','Length of paid maternity leave','Does the government administer 100% of maternity leave benefits?','Is there paid leave available to fathers?','Length of paid paternity leave', 'Is there paid parental leave?', 'Shared days','Days for the mother', 'Days for the father'])

# %%
df_entre.head()
# Out:
#         ID      economy wbcodev2      Region Income group  reportyr  \
# 0  AFG1971  Afghanistan      AFG  South Asia   Low income      1971
# 1  AFG1972  Afghanistan      AFG  South Asia   Low income      1972
# 2  AFG1973  Afghanistan      AFG  South Asia   Low income      1973
# 3  AFG1974  Afghanistan      AFG  South Asia   Low income      1974
# 4  AFG1975  Afghanistan      AFG  South Asia   Low income      1975
#
#    WBL INDEX  ENTREPRENEURSHIP  \
# 0       26.3                75
# 1       26.3                75
# 2       26.3                75
# 3       26.3                75
# 4       26.3                75
#
#   Can a woman sign a contract in the same way as a man?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
# ...

# %%
df_entre_renamed = df_entre.rename(columns = {'Can a woman sign a contract in the same way as a man?': 'sign_contract', 'Can a woman register a business in the same way as a man?': 'register_business', 'Can a woman open a bank account in the same way as a man?' : 'open_bank_account', 'Does the law prohibit discrimination in access to credit based on gender?': 'discrimination_credit_prohibited', 'Income group':'Income_group'})

# %%
df_entre_renamed.head()
# Out:
#         ID      economy wbcodev2      Region Income_group  reportyr  \
# 0  AFG1971  Afghanistan      AFG  South Asia   Low income      1971
# 1  AFG1972  Afghanistan      AFG  South Asia   Low income      1972
# 2  AFG1973  Afghanistan      AFG  South Asia   Low income      1973
# 3  AFG1974  Afghanistan      AFG  South Asia   Low income      1974
# 4  AFG1975  Afghanistan      AFG  South Asia   Low income      1975
#
#    WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# 0       26.3                75           Yes               Yes
# 1       26.3                75           Yes               Yes
# 2       26.3                75           Yes               Yes
# 3       26.3                75           Yes               Yes
# 4       26.3                75           Yes               Yes
#
#   open_bank_account discrimination_credit_prohibited
# 0               Yes                               No
# 1               Yes                               No
# ...

# %%
df_entre_renamed.to_csv(index=False)
# Out:
# 'ID,economy,wbcodev2,Region,Income_group,reportyr,WBL INDEX,ENTREPRENEURSHIP,sign_contract,register_business,open_bank_account,discrimination_credit_prohibited\r\nAFG1971,Afghanistan,AFG,South Asia,Low income,1971,26.3,75,Yes,Yes,Yes,No\r\nAFG1972,Afghanistan,AFG,South Asia,Low income,1972,26.3,75,Yes,Yes,Yes,No\r\nAFG1973,Afghanistan,AFG,South Asia,Low income,1973,26.3,75,Yes,Yes,Yes,No\r\nAFG1974,Afghanistan,AFG,South Asia,Low income,1974,26.3,75,Yes,Yes,Yes,No\r\nAFG1975,Afghanistan,AFG,South Asia,Low income,1975,26.3,75,Yes,Yes,Yes,No\r\nAFG1976,Afghanistan,AFG,South Asia,Low income,1976,26.3,75,Yes,Yes,Yes,No\r\nAFG1977,Afghanistan,AFG,South Asia,Low income,1977,26.3,75,Yes,Yes,Yes,No\r\nAFG1978,Afghanistan,AFG,South Asia,Low income,1978,26.3,75,Yes,Yes,Yes,No\r\nAFG1979,Afghanistan,AFG,South Asia,Low income,1979,26.3,75,Yes,Yes,Yes,No\r\nAFG1980,Afghanistan,AFG,South Asia,Low income,1980,26.3,75,Yes,Yes,Yes,No\r\nAFG1981,Afghanistan,AFG,South Asia,Low income,1981,26.3,75,Yes,Ye
# ...

# %%
df_entre_renamed.to_csv('entrepreneurship.csv')

# %%
low_income_sign_contract_yes = df_entre_renamed.loc[df_entre_renamed['sign_contract'] == 'Yes']
low_income_sign_contract_yes
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
low_income_sign_contract_no = df_entre_renamed.loc[df_entre_renamed['sign_contract'] == 'No']
low_income_sign_contract_no
# Out:
#            ID   economy wbcodev2              Region         Income_group  \
# 51    AGO1971    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 52    AGO1972    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 53    AGO1973    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 54    AGO1974    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 55    AGO1975    Angola      AGO  Sub-Saharan Africa  Lower middle income
# ...       ...       ...      ...                 ...                  ...
# 9643  ZWE1975  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9644  ZWE1976  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9645  ZWE1977  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9646  ZWE1978  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9647  ZWE1979  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
register_business_yes = df_entre_renamed.loc[df_entre_renamed['register_business'] == 'Yes']
register_business_yes
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
register_business_no = df_entre_renamed.loc[df_entre_renamed['register_business'] == 'No']
register_business_no
# Out:
#            ID   economy wbcodev2              Region         Income_group  \
# 51    AGO1971    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 52    AGO1972    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 53    AGO1973    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 54    AGO1974    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 55    AGO1975    Angola      AGO  Sub-Saharan Africa  Lower middle income
# ...       ...       ...      ...                 ...                  ...
# 9643  ZWE1975  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9644  ZWE1976  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9645  ZWE1977  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9646  ZWE1978  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9647  ZWE1979  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
open_bank_account_yes = df_entre_renamed.loc[df_entre_renamed['open_bank_account'] == 'Yes']
open_bank_account_yes
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
open_bank_account_no = df_entre_renamed.loc[df_entre_renamed['open_bank_account'] == 'No']
open_bank_account_no
# Out:
#            ID   economy wbcodev2              Region         Income_group  \
# 51    AGO1971    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 52    AGO1972    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 53    AGO1973    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 54    AGO1974    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 55    AGO1975    Angola      AGO  Sub-Saharan Africa  Lower middle income
# ...       ...       ...      ...                 ...                  ...
# 9643  ZWE1975  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9644  ZWE1976  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9645  ZWE1977  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9646  ZWE1978  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9647  ZWE1979  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
discrimination_credit_prohibited_yes = df_entre_renamed.loc[df_entre_renamed['discrimination_credit_prohibited'] == 'Yes']
discrimination_credit_prohibited_yes
# Out:
#            ID   economy wbcodev2              Region         Income_group  \
# 93    AGO2013    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 94    AGO2014    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 95    AGO2015    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 96    AGO2016    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 97    AGO2017    Angola      AGO  Sub-Saharan Africa  Lower middle income
# ...       ...       ...      ...                 ...                  ...
# 9685  ZWE2017  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
discrimination_credit_prohibited_no = df_entre_renamed.loc[df_entre_renamed['discrimination_credit_prohibited'] == 'No']
discrimination_credit_prohibited_no
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9663  ZWE1995     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9664  ZWE1996     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9665  ZWE1997     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9666  ZWE1998     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9667  ZWE1999     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
discrimination_credit_prohibited_no_by_region_income = (discrimination_credit_prohibited_no.groupby(['Region', 'Income_group'], as_index=False)['economy'].count())
discrimination_credit_prohibited_no_by_region_income
# Out:
#                         Region         Income_group  economy
# 0          East Asia & Pacific          High income      230
# 1          East Asia & Pacific  Lower middle income      494
# 2          East Asia & Pacific  Upper middle income      407
# 3        Europe & Central Asia          High income      164
# 4        Europe & Central Asia           Low income       35
# 5        Europe & Central Asia  Lower middle income      162
# 6        Europe & Central Asia  Upper middle income      620
# 7            High income: OECD          High income     1179
# 8    Latin America & Caribbean          High income      342
# 9    Latin America & Caribbean           Low income       51
# 10   Latin America & Caribbean  Lower middle income      159
# 11   Latin America & Caribbean  Upper middle income      889
# 12  Middle East & North Africa          High income      335
# 13  Middle East & North Africa           Low income      102
# ...

# %%
df_entre_renamed.sign_contract.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sign_contract_counts = df_entre_renamed['sign_contract'].value_counts()
sign_contract_counts
# Out:
# Yes    9124
# No      566
# Name: sign_contract, dtype: int64

# %%
register_business_counts = df_entre_renamed['register_business'].value_counts()
register_business_counts
# Out:
# Yes    8880
# No      810
# Name: register_business, dtype: int64

# %%
open_bank_account_counts = df_entre_renamed['open_bank_account'].value_counts()
open_bank_account_counts
# Out:
# Yes    8757
# No      933
# Name: open_bank_account, dtype: int64

# %%
discrimination_credit_prohibited_counts = df_entre_renamed['discrimination_credit_prohibited'].value_counts()
discrimination_credit_prohibited_counts
# Out:
# No     8440
# Yes    1250
# Name: discrimination_credit_prohibited, dtype: int64

# %%
All_countries_by_region = (df_entre_renamed.groupby(['Region'], as_index=False)['economy'].count())
All_countries_by_region
# Out:
#                        Region  economy
# 0         East Asia & Pacific     1275
# 1       Europe & Central Asia     1173
# 2           High income: OECD     1734
# 3   Latin America & Caribbean     1632
# 4  Middle East & North Africa     1020
# 5                  South Asia      408
# 6          Sub-Saharan Africa     2448

# %%
All_countries_by_region_income = (df_entre_renamed.groupby(['Region', 'Income_group'], as_index=False)['economy'].count())
All_countries_by_region_income
# Out:
#                         Region         Income_group  economy
# 0          East Asia & Pacific          High income      255
# 1          East Asia & Pacific  Lower middle income      612
# 2          East Asia & Pacific  Upper middle income      408
# 3        Europe & Central Asia          High income      204
# 4        Europe & Central Asia           Low income       51
# 5        Europe & Central Asia  Lower middle income      204
# 6        Europe & Central Asia  Upper middle income      714
# 7            High income: OECD          High income     1734
# 8    Latin America & Caribbean          High income      408
# 9    Latin America & Caribbean           Low income       51
# 10   Latin America & Caribbean  Lower middle income      204
# 11   Latin America & Caribbean  Upper middle income      969
# 12  Middle East & North Africa          High income      357
# 13  Middle East & North Africa           Low income      102
# ...

# %%
df_entre_renamed
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
plt.bar(All_countries_by_region_income.Income_group, All_countries_by_region_income.economy, linewidth=2)#, color='#a45c7c')
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Count of Economies')
plt.title('Economies in Dataset')
plt.show()

# %%
plt.bar(All_countries_by_region_income.Region, All_countries_by_region_income.economy, linewidth=2)#, color='#a45c7c'),
plt.bar(All_countries_by_region_income.Income_group, All_countries_by_region_income.economy, linewidth=2, color='#a45c7c')
plt.rcParams["figure.figsize"] = [15,10]
#plt.xticks(range(7))
#plt.xlabel('Days')
plt.xticks(rotation = 90)
plt.ylabel('Count of Economies')
plt.title('Economies in Dataset')
plt.show()

# %%
#x = plt.gca()

#All_countries_by_region_income.plot(kind='line',x='Income_group',y='economy',ax=ax)
#All_countries_by_region_income.plot(kind='line',x='Region',y='economy',ax=ax)

#plt.show()

# %%
df_entre_renamed.isnull().sum()
# Out:
# ID                                  0
# economy                             0
# wbcodev2                            0
# Region                              0
# Income_group                        0
# reportyr                            0
# WBL INDEX                           0
# ENTREPRENEURSHIP                    0
# sign_contract                       0
# register_business                   0
# open_bank_account                   0
# discrimination_credit_prohibited    0
# dtype: int64

# %%
country_count = {}
for i in df_entre_renamed['economy']:
    if i in country_count.keys():
       country_count[i] += 1
    else:
        country_count[i] = 1
country_count
# Out:
# {'Afghanistan': 51,
#  'Angola': 51,
#  'Albania': 51,
#  'United Arab Emirates': 51,
#  'Argentina': 51,
#  'Armenia': 51,
#  'Antigua and Barbuda': 51,
#  'Australia': 51,
#  'Austria': 51,
#  'Azerbaijan': 51,
#  'Burundi': 51,
#  'Belgium': 51,
#  'Benin': 51,
#  'Burkina Faso': 51,
#  'Bangladesh': 51,
#  'Bulgaria': 51,
#  'Bahrain': 51,
#  'Bahamas, The': 51,
#  'Bosnia and Herzegovina': 51,
#  'Belarus': 51,
#  'Belize': 51,
#  'Bolivia': 51,
#  'Brazil': 51,
#  'Barbados': 51,
#  'Brunei Darussalam': 51,
#  'Bhutan': 51,
#  'Botswana': 51,
#  'Central African Republic': 51,
#  'Canada': 51,
#  'Switzerland': 51,
#  'Chile': 51,
#  'China': 51,
#  "Côte d'Ivoire": 51,
#  'Cameroon': 51,
#  'Congo, Rep.': 51,
#  'Colombia': 51,
#  'Comoros': 51,
#  'Cabo Verde': 51,
#  'Costa Rica': 51,
#  'Cyprus': 51,
#  'Czech Republic': 51,
#  'Germany': 51,
#  'Djibouti': 51,
#  'Dominica': 51,
#  'Denmark': 51,
#  'Dominican Republic': 51,
#  'Algeria': 51,
#  'Ecuador': 51,
# ...

# %%
country_count = pd.DataFrame.from_dict(country_count, orient='index', columns=['Count'])
country_count
# Out:
#                       Count
# Afghanistan              51
# Angola                   51
# Albania                  51
# United Arab Emirates     51
# Argentina                51
# ...                     ...
# Yemen, Rep.              51
# South Africa             51
# Congo, Dem. Rep.         51
# Zambia                   51
# Zimbabwe                 51
#
# [190 rows x 1 columns]

# %%
country_count_T = country_count.transpose()
country_count_T
# Out:
#        Afghanistan  Angola  Albania  United Arab Emirates  Argentina  Armenia  \
# Count           51      51       51                    51         51       51
#
#        Antigua and Barbuda  Australia  Austria  Azerbaijan  ...  \
# Count                   51         51       51          51  ...
#
#        Venezuela, RB  Vietnam  Vanuatu  West Bank and Gaza  Samoa  \
# Count             51       51       51                  51     51
#
#        Yemen, Rep.  South Africa  Congo, Dem. Rep.  Zambia  Zimbabwe
# Count           51            51                51      51        51
#
# [1 rows x 190 columns]

# %%
country_count['countries'] = country_count
country_count
# Out:
#                       Count  countries
# Afghanistan              51         51
# Angola                   51         51
# Albania                  51         51
# United Arab Emirates     51         51
# Argentina                51         51
# ...                     ...        ...
# Yemen, Rep.              51         51
# South Africa             51         51
# Congo, Dem. Rep.         51         51
# Zambia                   51         51
# Zimbabwe                 51         51
#
# [190 rows x 2 columns]

# %%
df_entre_renamed
# Out:
#            ID      economy wbcodev2              Region         Income_group  \
# 0     AFG1971  Afghanistan      AFG          South Asia           Low income
# 1     AFG1972  Afghanistan      AFG          South Asia           Low income
# 2     AFG1973  Afghanistan      AFG          South Asia           Low income
# 3     AFG1974  Afghanistan      AFG          South Asia           Low income
# 4     AFG1975  Afghanistan      AFG          South Asia           Low income
# ...       ...          ...      ...                 ...                  ...
# 9685  ZWE2017     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021     Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
# ...

# %%
df_entre_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                9690 non-null   object
#  1   economy                           9690 non-null   object
#  2   wbcodev2                          9690 non-null   object
#  3   Region                            9690 non-null   object
#  4   Income_group                      9690 non-null   object
#  5   reportyr                          9690 non-null   int64
#  6   WBL INDEX                         9690 non-null   float64
#  7   ENTREPRENEURSHIP                  9690 non-null   int64
#  8   sign_contract                     9690 non-null   object
#  9   register_business                 9690 non-null   object
#  10  open_bank_account                 9690 non-null   object
# ...

# %%
df_entre_renamed['Income_group'].value_counts()
# Out:
# High income            3060
# Upper middle income    2652
# Lower middle income    2550
# Low income             1428
# Name: Income_group, dtype: int64

# %%
df_low_income = df_entre_renamed.loc[df_entre_renamed['Income_group'] == 'Low income']
df_low_income.shape
# Out:
# (1428, 12)

# %%
df_low_income
# Out:
#            ID           economy wbcodev2              Region Income_group  \
# 0     AFG1971       Afghanistan      AFG          South Asia   Low income
# 1     AFG1972       Afghanistan      AFG          South Asia   Low income
# 2     AFG1973       Afghanistan      AFG          South Asia   Low income
# 3     AFG1974       Afghanistan      AFG          South Asia   Low income
# 4     AFG1975       Afghanistan      AFG          South Asia   Low income
# ...       ...               ...      ...                 ...          ...
# 9583  ZAR2017  Congo, Dem. Rep.      ZAR  Sub-Saharan Africa   Low income
# 9584  ZAR2018  Congo, Dem. Rep.      ZAR  Sub-Saharan Africa   Low income
# 9585  ZAR2019  Congo, Dem. Rep.      ZAR  Sub-Saharan Africa   Low income
# 9586  ZAR2020  Congo, Dem. Rep.      ZAR  Sub-Saharan Africa   Low income
# 9587  ZAR2021  Congo, Dem. Rep.      ZAR  Sub-Saharan Africa   Low income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
df_low_income_sign_contract_yes = df_low_income.loc[df_low_income['sign_contract'] == 'Yes']
df_low_income_sign_contract_yes
# Out:
#            ID           economy wbcodev2                      Region  \
# 0     AFG1971       Afghanistan      AFG                  South Asia
# 1     AFG1972       Afghanistan      AFG                  South Asia
# 2     AFG1973       Afghanistan      AFG                  South Asia
# 3     AFG1974       Afghanistan      AFG                  South Asia
# 4     AFG1975       Afghanistan      AFG                  South Asia
# ...       ...               ...      ...                         ...
# 9485  YEM2021       Yemen, Rep.      YEM  Middle East & North Africa
# 9584  ZAR2018  Congo, Dem. Rep.      ZAR          Sub-Saharan Africa
# 9585  ZAR2019  Congo, Dem. Rep.      ZAR          Sub-Saharan Africa
# 9586  ZAR2020  Congo, Dem. Rep.      ZAR          Sub-Saharan Africa
# 9587  ZAR2021  Congo, Dem. Rep.      ZAR          Sub-Saharan Africa
#
#      Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract  \
# ...

# %%
df_low_income_sign_contract_no = df_low_income.loc[df_low_income['sign_contract'] == 'No']
df_low_income_sign_contract_no
# Out:
#            ID           economy wbcodev2                     Region  \
# 3672  HTI1971             Haiti      HTI  Latin America & Caribbean
# 3673  HTI1972             Haiti      HTI  Latin America & Caribbean
# 3674  HTI1973             Haiti      HTI  Latin America & Caribbean
# 3675  HTI1974             Haiti      HTI  Latin America & Caribbean
# 3676  HTI1975             Haiti      HTI  Latin America & Caribbean
# ...       ...               ...      ...                        ...
# 9579  ZAR2013  Congo, Dem. Rep.      ZAR         Sub-Saharan Africa
# 9580  ZAR2014  Congo, Dem. Rep.      ZAR         Sub-Saharan Africa
# 9581  ZAR2015  Congo, Dem. Rep.      ZAR         Sub-Saharan Africa
# 9582  ZAR2016  Congo, Dem. Rep.      ZAR         Sub-Saharan Africa
# 9583  ZAR2017  Congo, Dem. Rep.      ZAR         Sub-Saharan Africa
#
#      Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract  \
# 3672   Low income      1971       37.5                 0            No
# ...

# %%
df_low_income_country_count = df_low_income['economy'].value_counts()
df_low_income_country_count
# Out:
# Guinea                      51
# Somalia                     51
# Haiti                       51
# Niger                       51
# Central African Republic    51
# Uganda                      51
# Togo                        51
# Liberia                     51
# Yemen, Rep.                 51
# Mozambique                  51
# Guinea-Bissau               51
# Malawi                      51
# Gambia, The                 51
# Madagascar                  51
# Chad                        51
# Sudan                       51
# Afghanistan                 51
# Burundi                     51
# South Sudan                 51
# Eritrea                     51
# Rwanda                      51
# Mali                        51
# Sierra Leone                51
# Tajikistan                  51
# Burkina Faso                51
# Ethiopia                    51
# Congo, Dem. Rep.            51
# Syrian Arab Republic        51
# Name: economy, dtype: int64

# %%
country_region_low = (df_low_income.groupby(['Region'], as_index=False)['economy'].count())
country_region_low
# Out:
#                        Region  economy
# 0       Europe & Central Asia       51
# 1   Latin America & Caribbean       51
# 2  Middle East & North Africa      102
# 3                  South Asia       51
# 4          Sub-Saharan Africa     1173

# %%
df_lower_middle_income = df_entre_renamed.loc[df_entre_renamed['Income_group'] == 'Lower middle income']
df_lower_middle_income.shape
# Out:
# (2550, 12)

# %%
df_lower_middle_income
# Out:
#            ID   economy wbcodev2              Region         Income_group  \
# 51    AGO1971    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 52    AGO1972    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 53    AGO1973    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 54    AGO1974    Angola      AGO  Sub-Saharan Africa  Lower middle income
# 55    AGO1975    Angola      AGO  Sub-Saharan Africa  Lower middle income
# ...       ...       ...      ...                 ...                  ...
# 9685  ZWE2017  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9686  ZWE2018  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9687  ZWE2019  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9688  ZWE2020  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
# 9689  ZWE2021  Zimbabwe      ZWE  Sub-Saharan Africa  Lower middle income
#
#       reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract register_business  \
# ...

# %%
country_region_lower_middle = (df_lower_middle_income.groupby(['Region'], as_index=False)['economy'].count())
country_region_lower_middle
# Out:
#                        Region  economy
# 0         East Asia & Pacific      612
# 1       Europe & Central Asia      204
# 2   Latin America & Caribbean      204
# 3  Middle East & North Africa      306
# 4                  South Asia      306
# 5          Sub-Saharan Africa      918

# %%
df_lower_middle_income_country_count = df_lower_middle_income['economy'].value_counts()
df_lower_middle_income_country_count
# Out:
# Ukraine                  51
# Nicaragua                51
# Sri Lanka                51
# Myanmar                  51
# Djibouti                 51
# Kenya                    51
# São Tomé and Príncipe    51
# Eswatini                 51
# Zambia                   51
# Zimbabwe                 51
# Morocco                  51
# Lao PDR                  51
# Kiribati                 51
# Cabo Verde               51
# Uzbekistan               51
# Senegal                  51
# Moldova                  51
# Nigeria                  51
# West Bank and Gaza       51
# Timor-Leste              51
# Bhutan                   51
# Cambodia                 51
# Vietnam                  51
# Bolivia                  51
# Vanuatu                  51
# Congo, Rep.              51
# Philippines              51
# Honduras                 51
# Kyrgyz Republic          51
# Nepal                    51
# Egypt, Arab Rep.         51
# Papua New Guinea         51
# Mauritania               51
# ...

# %%
df_upper_middle_income = df_entre_renamed.loc[df_entre_renamed['Income_group'] == 'Upper middle income']
df_upper_middle_income.shape
# Out:
# (2652, 12)

# %%
df_upper_middle_income
# Out:
#            ID       economy wbcodev2                 Region  \
# 102   ALB1971       Albania      ALB  Europe & Central Asia
# 103   ALB1972       Albania      ALB  Europe & Central Asia
# 104   ALB1973       Albania      ALB  Europe & Central Asia
# 105   ALB1974       Albania      ALB  Europe & Central Asia
# 106   ALB1975       Albania      ALB  Europe & Central Asia
# ...       ...           ...      ...                    ...
# 9532  ZAF2017  South Africa      ZAF     Sub-Saharan Africa
# 9533  ZAF2018  South Africa      ZAF     Sub-Saharan Africa
# 9534  ZAF2019  South Africa      ZAF     Sub-Saharan Africa
# 9535  ZAF2020  South Africa      ZAF     Sub-Saharan Africa
# 9536  ZAF2021  South Africa      ZAF     Sub-Saharan Africa
#
#              Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP  \
# 102   Upper middle income      1971       59.4                75
# 103   Upper middle income      1972       59.4                75
# ...

# %%
country_region_upper_middle = (df_upper_middle_income.groupby(['Region'], as_index=False)['economy'].count())
country_region_upper_middle
# Out:
#                        Region  economy
# 0         East Asia & Pacific      408
# 1       Europe & Central Asia      714
# 2   Latin America & Caribbean      969
# 3  Middle East & North Africa      255
# 4                  South Asia       51
# 5          Sub-Saharan Africa      255

# %%
df_upper_middle_income_country_count = df_upper_middle_income['economy'].value_counts()
df_upper_middle_income_country_count
# Out:
# Venezuela, RB                     51
# Mexico                            51
# Guyana                            51
# Brazil                            51
# Guatemala                         51
# Armenia                           51
# Lebanon                           51
# Fiji                              51
# Libya                             51
# Suriname                          51
# Gabon                             51
# Iraq                              51
# Samoa                             51
# Dominica                          51
# Maldives                          51
# Bosnia and Herzegovina            51
# St. Vincent and the Grenadines    51
# Marshall Islands                  51
# South Africa                      51
# Dominican Republic                51
# Indonesia                         51
# Ecuador                           51
# Jordan                            51
# China                             51
# Paraguay                          51
# ...

# %%
df_high_income = df_entre_renamed.loc[df_entre_renamed['Income_group'] == 'High income']
df_high_income.shape
# Out:
# (3060, 12)

# %%
df_high_income
# Out:
#            ID               economy wbcodev2                      Region  \
# 153   ARE1971  United Arab Emirates      ARE  Middle East & North Africa
# 154   ARE1972  United Arab Emirates      ARE  Middle East & North Africa
# 155   ARE1973  United Arab Emirates      ARE  Middle East & North Africa
# 156   ARE1974  United Arab Emirates      ARE  Middle East & North Africa
# 157   ARE1975  United Arab Emirates      ARE  Middle East & North Africa
# ...       ...                   ...      ...                         ...
# 9073  USA2017         United States      USA           High income: OECD
# 9074  USA2018         United States      USA           High income: OECD
# 9075  USA2019         United States      USA           High income: OECD
# 9076  USA2020         United States      USA           High income: OECD
# 9077  USA2021         United States      USA           High income: OECD
#
#      Income_group  reportyr  WBL INDEX  ENTREPRENEURSHIP sign_contract  \
# ...

# %%
country_region_high_income = (df_high_income.groupby(['Region'], as_index=False)['economy'].count())
country_region_high_income
# Out:
#                        Region  economy
# 0         East Asia & Pacific      255
# 1       Europe & Central Asia      204
# 2           High income: OECD     1734
# 3   Latin America & Caribbean      408
# 4  Middle East & North Africa      357
# 5          Sub-Saharan Africa      102

# %%
df_high_income_country_count = df_high_income['economy'].value_counts()
df_high_income_country_count
# Out:
# Barbados                51
# Italy                   51
# Singapore               51
# Hong Kong SAR, China    51
# Chile                   51
# Qatar                   51
# Switzerland             51
# Bahrain                 51
# United Arab Emirates    51
# Czech Republic          51
# Slovak Republic         51
# Saudi Arabia            51
# Israel                  51
# Bahamas, The            51
# Norway                  51
# San Marino              51
# Brunei Darussalam       51
# Seychelles              51
# Lithuania               51
# Estonia                 51
# Iceland                 51
# New Zealand             51
# Luxembourg              51
# Oman                    51
# Japan                   51
# Sweden                  51
# United States           51
# Ireland                 51
# Taiwan, China           51
# Romania                 51
# Canada                  51
# Cyprus                  51
# Netherlands             51
# Spain                   51
# ...
