# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
female_business_owner = pd.read_csv('../data/female_business_owner_data.csv', engine='python')
female_business_owner.shape
# Out:
# (365, 18)

# %%
female_business_owner.head()
# Out:
#        Country Income group  Year Number of female business owners of new LLC  \
# 0  Afghanistan   Low income  2014                                          65
# 1  Afghanistan   Low income  2015                                          45
# 2  Afghanistan   Low income  2016                                          65
# 3  Afghanistan   Low income  2017                                          88
# 4  Afghanistan   Low income  2018                                         177
#
#   Number of male business owners of new LLC  \
# 0                                     5,043
# 1                                     4,704
# 2                                     5,036
# 3                                     6,047
# 4                                     8,482
#
#   Total number of business owners of new LLC  \
# 0                                      5,108
# 1                                      4,749
# 2                                      5,101
# ...

# %%
female_business_owner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      365 non-null    object
#  1   Income group                                 365 non-null    object
#  2   Year                                         365 non-null    int64
#  3   Number of female business owners of new LLC  250 non-null    object
#  4   Number of male business owners of new LLC    250 non-null    object
#  5   Total number of business owners of new LLC   250 non-null    object
#  6   Number of female sole proprietors            249 non-null    object
#  7   Number of male sole proprietors              249 non-null    object
#  8   Total number of sole proprietors             249 non-null    object
# ...

# %%
female_business_owner.isnull().sum()
# Out:
# Country                                          0
# Income group                                     0
# Year                                             0
# Number of female business owners of new LLC    115
# Number of male business owners of new LLC      115
# Total number of business owners of new LLC     115
# Number of female sole proprietors              116
# Number of male sole proprietors                116
# Total number of sole proprietors               116
# Number of female directors of new LLC          163
# Number of male directors of new LLC            163
# Total number of directors of new LLC           163
# Share of female business owners of new LLC     115
# Share of male business owners of new LLC       115
# Share of female sole proprietors               116
# Share of male sole proprietors                 116
# Share of female directors of new LLC           186
# Share of male directors of new LLC             186
# dtype: int64

# %%
female_business_owner_drop = female_business_owner.dropna()
#female_business_owner_drop = female_business_owner.fillna(0)

# %%
female_business_owner_drop.isnull().sum()
# Out:
# Country                                        0
# Income group                                   0
# Year                                           0
# Number of female business owners of new LLC    0
# Number of male business owners of new LLC      0
# Total number of business owners of new LLC     0
# Number of female sole proprietors              0
# Number of male sole proprietors                0
# Total number of sole proprietors               0
# Number of female directors of new LLC          0
# Number of male directors of new LLC            0
# Total number of directors of new LLC           0
# Share of female business owners of new LLC     0
# Share of male business owners of new LLC       0
# Share of female sole proprietors               0
# Share of male sole proprietors                 0
# Share of female directors of new LLC           0
# Share of male directors of new LLC             0
# dtype: int64

# %%
female_business_owner_drop.to_csv('female_businesses_Tableau.csv')

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop.tail()
# Out:
#     Country         Income group  Year  \
# 360  Zambia  Lower middle income  2014
# 361  Zambia  Lower middle income  2015
# 362  Zambia  Lower middle income  2016
# 363  Zambia  Lower middle income  2017
# 364  Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 360                                       4,611
# 361                                       4,627
# 362                                       4,041
# 363                                       4,059
# 364                                       4,481
#
#     Number of male business owners of new LLC  \
# 360                                    17,184
# 361                                    15,545
# 362                                    13,905
# 363                                    14,931
# 364                                    16,092
#
#     Total number of business owners of new LLC  \
# 360                                     21,795
# 361                                     20,172
# ...

# %%
female_business_owner_drop['Share of male directors of new LLC'] = female_business_owner_drop['Share of male directors of new LLC'].str.replace('%', '')
# Out:
# <ipython-input-10-b4b18ec28646>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LLC'] = female_business_owner_drop['Share of male directors of new LLC'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female directors of new LLC'] = female_business_owner_drop['Share of female directors of new LLC'].str.replace('%', '')
# Out:
# <ipython-input-11-b746f20acb96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LLC'] = female_business_owner_drop['Share of female directors of new LLC'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-12-21bbfdc729c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-13-6f60126ae5f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male business owners of new LLC'] = female_business_owner_drop['Share of male business owners of new LLC'].str.replace('%', '')
# Out:
# <ipython-input-14-6d09245ecf0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLC'] = female_business_owner_drop['Share of male business owners of new LLC'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female business owners of new LLC'] = female_business_owner_drop['Share of female business owners of new LLC'].str.replace('%', '')
# Out:
# <ipython-input-15-dc01fd77be67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLC'] = female_business_owner_drop['Share of female business owners of new LLC'].str.replace('%', '')

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      139 non-null    object
#  1   Income group                                 139 non-null    object
#  2   Year                                         139 non-null    int64
#  3   Number of female business owners of new LLC  139 non-null    object
#  4   Number of male business owners of new LLC    139 non-null    object
#  5   Total number of business owners of new LLC   139 non-null    object
#  6   Number of female sole proprietors            139 non-null    object
#  7   Number of male sole proprietors              139 non-null    object
#  8   Total number of sole proprietors             139 non-null    object
# ...

# %%
female_business_owner_drop['Share of male directors of new LLC'] = female_business_owner_drop['Share of male directors of new LLC'].astype(float)
# Out:
# <ipython-input-18-e57e04756541>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LLC'] = female_business_owner_drop['Share of male directors of new LLC'].astype(float)

# %%
female_business_owner_drop['Share of female directors of new LLC'] = female_business_owner_drop['Share of female directors of new LLC'].astype(float)
# Out:
# <ipython-input-19-83e39ca91d18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LLC'] = female_business_owner_drop['Share of female directors of new LLC'].astype(float)

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)
# Out:
# <ipython-input-20-2ef0581b24e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)
# Out:
# <ipython-input-21-d20f7bc39483>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of male business owners of new LLC'] = female_business_owner_drop['Share of male business owners of new LLC'].astype(float)
# Out:
# <ipython-input-22-023b6115691c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLC'] = female_business_owner_drop['Share of male business owners of new LLC'].astype(float)

# %%
female_business_owner_drop['Share of female business owners of new LLC'] = female_business_owner_drop['Share of female business owners of new LLC'].astype(float)
# Out:
# <ipython-input-23-20a42fb4e8ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLC'] = female_business_owner_drop['Share of female business owners of new LLC'].astype(float)

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop['Total number of directors of new LLC'] = female_business_owner_drop['Total number of directors of new LLC'].str.replace(',', '')
# Out:
# <ipython-input-26-327ce5c7ad43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LLC'] = female_business_owner_drop['Total number of directors of new LLC'].str.replace(',', '')

# %%
female_business_owner_drop['Total number of directors of new LLC'] = female_business_owner_drop['Total number of directors of new LLC'].astype(int)
# Out:
# <ipython-input-27-eec92d7a6bfa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LLC'] = female_business_owner_drop['Total number of directors of new LLC'].astype(int)

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop.tail(50)
# Out:
#            Country         Income group  Year  \
# 223          Nepal           Low income  2017
# 224          Nepal           Low income  2018
# 231        Nigeria  Lower middle income  2015
# 232        Nigeria  Lower middle income  2016
# 233        Nigeria  Lower middle income  2017
# 234        Nigeria  Lower middle income  2018
# 236         Norway          High income  2015
# 237         Norway          High income  2016
# 238         Norway          High income  2017
# 239         Norway          High income  2018
# 240           Oman          High income  2014
# 241           Oman          High income  2015
# 242           Oman          High income  2016
# 243           Oman          High income  2017
# 244           Oman          High income  2018
# 260          Qatar          High income  2014
# 261          Qatar          High income  2015
# 262          Qatar          High income  2016
# 263          Qatar          High income  2017
# ...

# %%
female_business_owner_drop['Number of male directors of new LLC'] = female_business_owner_drop['Number of male directors of new LLC'].str.replace(',', '')
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].str.replace(',', '')
female_business_owner_drop['Total number of business owners of new LLC'] = female_business_owner_drop['Total number of business owners of new LLC'].str.replace(',', '')
female_business_owner_drop['Number of male business owners of new LLC'] = female_business_owner_drop['Number of male business owners of new LLC'].str.replace(',', '')
female_business_owner_drop['Number of female directors of new LLC'] = female_business_owner_drop['Number of female directors of new LLC'].str.replace(',', '')
# Out:
# <ipython-input-30-8f01f8e8455b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LLC'] = female_business_owner_drop['Number of male directors of new LLC'].str.replace(',', '')
# <ipython-input-30-8f01f8e8455b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#     Number of female business owners of new LLC  \
# 0                                            65
# 1                                            45
# 2                                            65
# 3                                            88
# 4                                           177
# ..                                          ...
# 360                                       4,611
# ...

# %%
female_business_owner_drop['Number of male directors of new LLC'] = female_business_owner_drop['Number of male directors of new LLC'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Number of female directors of new LLC'] = female_business_owner_drop['Number of female directors of new LLC'].astype(int)
# Out:
# <ipython-input-32-b43f05597708>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LLC'] = female_business_owner_drop['Number of male directors of new LLC'].astype(int)
# <ipython-input-32-b43f05597708>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      139 non-null    object
#  1   Income group                                 139 non-null    object
#  2   Year                                         139 non-null    int64
#  3   Number of female business owners of new LLC  139 non-null    object
#  4   Number of male business owners of new LLC    139 non-null    object
#  5   Total number of business owners of new LLC   139 non-null    object
#  6   Number of female sole proprietors            139 non-null    object
#  7   Number of male sole proprietors              139 non-null    int32
#  8   Total number of sole proprietors             139 non-null    int32
# ...

# %%
female_business_owner_drop['Number of female business owners of new LLC'] = female_business_owner_drop['Number of female business owners of new LLC'].str.replace(',', '')
female_business_owner_drop['Number of male business owners of new LLC'] = female_business_owner_drop['Number of male business owners of new LLC'].str.replace(',', '')
female_business_owner_drop['Total number of business owners of new LLC'] = female_business_owner_drop['Total number of business owners of new LLC'].str.replace(',', '')
female_business_owner_drop['Number of female sole proprietors'] = female_business_owner_drop['Number of female sole proprietors'].str.replace(',', '')
# Out:
# <ipython-input-34-dd08aaa954bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of female business owners of new LLC'] = female_business_owner_drop['Number of female business owners of new LLC'].str.replace(',', '')
# <ipython-input-34-dd08aaa954bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
female_business_owner_drop['Number of female business owners of new LLC'] = female_business_owner_drop['Number of female business owners of new LLC'].astype(int)
female_business_owner_drop['Number of male business owners of new LLC'] = female_business_owner_drop['Number of male business owners of new LLC'].astype(int)
female_business_owner_drop['Total number of business owners of new LLC'] = female_business_owner_drop['Total number of business owners of new LLC'].astype(int)
female_business_owner_drop['Number of female sole proprietors'] = female_business_owner_drop['Number of female sole proprietors'].astype(int)
# Out:
# <ipython-input-35-4eebfa3507ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of female business owners of new LLC'] = female_business_owner_drop['Number of female business owners of new LLC'].astype(int)
# <ipython-input-35-4eebfa3507ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male business owners of new LLC'] = female_business_owner_drop['Number of male business owners of new LLC'].astype(int)
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#      Number of female business owners of new LLC  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                         4611
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      139 non-null    object
#  1   Income group                                 139 non-null    object
#  2   Year                                         139 non-null    int64
#  3   Number of female business owners of new LLC  139 non-null    int32
#  4   Number of male business owners of new LLC    139 non-null    int32
#  5   Total number of business owners of new LLC   139 non-null    int32
#  6   Number of female sole proprietors            139 non-null    int32
#  7   Number of male sole proprietors              139 non-null    int32
#  8   Total number of sole proprietors             139 non-null    int32
# ...

# %%
female_business_owner_drop['Year'].apply(np.floor)
# Out:
# 0      2014.0
# 1      2015.0
# 2      2016.0
# 3      2017.0
# 4      2018.0
#         ...
# 360    2014.0
# 361    2015.0
# 362    2016.0
# 363    2017.0
# 364    2018.0
# Name: Year, Length: 139, dtype: float64

# %%
female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)
# Out:
# <ipython-input-39-58c5345046ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      139 non-null    object
#  1   Income group                                 139 non-null    object
#  2   Year                                         139 non-null    int32
#  3   Number of female business owners of new LLC  139 non-null    int32
#  4   Number of male business owners of new LLC    139 non-null    int32
#  5   Total number of business owners of new LLC   139 non-null    int32
#  6   Number of female sole proprietors            139 non-null    int32
#  7   Number of male sole proprietors              139 non-null    int32
#  8   Total number of sole proprietors             139 non-null    int32
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#      Number of female business owners of new LLC  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                         4611
# ...

# %%
female_business_owner_drop_renamed = female_business_owner_drop.rename(columns = {'Income group': 'Income_group', 'Number of female business owners of new LLC': 'Number_of_female_business_owners_of_new_LLC', 'Number of male business owners of new LLC':'Number_of_male_business_owners_of_new_LLC','Total number of business owners of new LLC':'Total_number_of_business_owners_of_new_LLC', 'Number of female sole proprietors':'Number_of_female_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Number of male sole proprietors': 'Number_of_male_sole_proprietors', 'Number of female business owners of new LLC': 'Number_of_female_business_owners_of_new_LLC', 'Number of male business owners of new LLC':'Number_of_male_business_owners_of_new_LLC','Total number of sole proprietors':'Total_number_of_sole_proprietors', 'Number of female directors of new LLC':'Number_of_female_directors_of_new_LLC'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Total number of business owners of new LLC': 'Total_number_of_business_owners_of_new_LLC', 'Number of female business owners of new LLC': 'Number_of_female_business_owners_of_new_LLC', 'Number of male business owners of new LLC':'Number_of_male_business_owners_of_new_LLC','Total number of business owners of new LLC':'Total_number_of_business_owners_of_new_LLC', 'Number of female sole proprietors':'Number_of_female_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Number of male directors of new LLC':'Number_of_male_directors_of_new_LLC', 'Number of male sole proprietors':'Number_of_male_sole_proprietors'})

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Total number of directors of new LLC':'Total_number_of_directors_of_new_LLC', 'Share of female business owners of new LLC':'Share_of_female_business_owners_of_new_LLC' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male business owners of new LLC':'Share_of_male_business_owners_of_new_LLC' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of female sole proprietors':'Share_of_female_sole_proprietors' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male sole proprietors':'Share_of_male_sole_proprietors' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of female directors of new LLC':'Share_of_female_directors_of_new_LLC' })

# %%
female_business_owner_drop_renamed = female_business_owner_drop_renamed.rename(columns = {'Share of male directors of new LLC':'Share_of_male_directors_of_new_LLC' })

# %%
female_business_owner_drop_renamed
# Out:
#          Country         Income_group  Year  \
# 0    Afghanistan           Low income  2014
# 1    Afghanistan           Low income  2015
# 2    Afghanistan           Low income  2016
# 3    Afghanistan           Low income  2017
# 4    Afghanistan           Low income  2018
# ..           ...                  ...   ...
# 360       Zambia  Lower middle income  2014
# 361       Zambia  Lower middle income  2015
# 362       Zambia  Lower middle income  2016
# 363       Zambia  Lower middle income  2017
# 364       Zambia  Lower middle income  2018
#
#      Number_of_female_business_owners_of_new_LLC  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                         4611
# ...

# %%
#female_business_owner_drop.to_csv('female_business_owner_prep.csv')

# %%
#female_business_owner_drop_renamed.to_csv('female_business_owner_renamed.csv')

# %%
fem_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_business_owners_of_new_LLC'].mean())
fem_LLCs_income
# Out:
#           Income_group  Number_of_female_business_owners_of_new_LLC
# 0          High income                                  3876.250000
# 1           Low income                                  1027.066667
# 2  Lower middle income                                 29368.960000
# 3  Upper middle income                                  8179.018182

# %%
fem_sole_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_sole_proprietors'].mean())
fem_sole_income
# Out:
#           Income_group  Number_of_female_sole_proprietors
# 0          High income                        4024.000000
# 1           Low income                        5731.666667
# 2  Lower middle income                       11952.520000
# 3  Upper middle income                       21919.145455

# %%
fem_sole__share_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Share_of_female_sole_proprietors'].mean())
fem_sole__share_income
# Out:
#           Income_group  Share_of_female_sole_proprietors
# 0          High income                         36.488636
# 1           Low income                         18.880000
# 2  Lower middle income                         31.688000
# 3  Upper middle income                         35.110909

# %%
fem_sole__share_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Share_of_female_sole_proprietors'].median())
fem_sole__share_income
# Out:
#           Income_group  Share_of_female_sole_proprietors
# 0          High income                             35.65
# 1           Low income                             10.90
# 2  Lower middle income                             33.00
# 3  Upper middle income                             37.00

# %%
fem_directors_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_female_directors_of_new_LLC'].mean())
fem_directors_income
# Out:
#           Income_group  Number_of_female_directors_of_new_LLC
# 0          High income                            2765.409091
# 1           Low income                             365.866667
# 2  Lower middle income                           14016.160000
# 3  Upper middle income                            4516.800000

# %%
High_income_average = fem_directors_income.query('Income_group == "High income"')
High_income_average
# Out:
#   Income_group  Number_of_female_directors_of_new_LLC
# 0  High income                            2765.409091

# %%
High_income_average.round(0)
High_income_average['Number_of_female_directors_of_new_LLC'] = High_income_average['Number_of_female_directors_of_new_LLC'].astype(int)
# Out:
# <ipython-input-59-21ac59710779>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   High_income_average['Number_of_female_directors_of_new_LLC'] = High_income_average['Number_of_female_directors_of_new_LLC'].astype(int)

# %%
High_income_average.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Income_group                           1 non-null      object
#  1   Number_of_female_directors_of_new_LLC  1 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 20.0+ bytes

# %%
High_income_average
# Out:
#   Income_group  Number_of_female_directors_of_new_LLC
# 0  High income                                   2765

# %%
female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)
# Out:
# <ipython-input-62-58c5345046ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Year'] = female_business_owner_drop['Year'].astype(int)

# %%
High_income_average.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Income_group                           1 non-null      object
#  1   Number_of_female_directors_of_new_LLC  1 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 20.0+ bytes

# %%
High_income_sub = female_business_owner_drop_renamed.query('Income_group == "High income"')
High_income_sub.head(2)
# Out:
#     Country Income_group  Year  Number_of_female_business_owners_of_new_LLC  \
# 75  Denmark  High income  2014                                         3715
# 76  Denmark  High income  2015                                         5423
#
#     Number_of_male_business_owners_of_new_LLC  \
# 75                                      16556
# 76                                      21724
#
#     Total_number_of_business_owners_of_new_LLC  \
# 75                                       20271
# 76                                       27147
#
#     Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 75                              11369                            20919
# 76                              13240                            22204
#
#     Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LLC  \
# 75                             32288                                   1055
# ...

# %%
High_income_sub.head()
# Out:
#     Country Income_group  Year  Number_of_female_business_owners_of_new_LLC  \
# 75  Denmark  High income  2014                                         3715
# 76  Denmark  High income  2015                                         5423
# 77  Denmark  High income  2016                                         6286
# 78  Denmark  High income  2017                                         7154
# 79  Denmark  High income  2018                                         7380
#
#     Number_of_male_business_owners_of_new_LLC  \
# 75                                      16556
# 76                                      21724
# 77                                      24924
# 78                                      28250
# 79                                      28550
#
#     Total_number_of_business_owners_of_new_LLC  \
# 75                                       20271
# 76                                       27147
# 77                                       31210
# ...

# %%
High_income_sub['difference_to_average_directors'] = High_income_sub['Number_of_female_directors_of_new_LLC'] - High_income_average['Number_of_female_directors_of_new_LLC'].values[0]
# Out:
# <ipython-input-66-168ea98be063>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   High_income_sub['difference_to_average_directors'] = High_income_sub['Number_of_female_directors_of_new_LLC'] - High_income_average['Number_of_female_directors_of_new_LLC'].values[0]

# %%
High_income_sub
# Out:
#            Country Income_group  Year  \
# 75         Denmark  High income  2014
# 76         Denmark  High income  2015
# 77         Denmark  High income  2016
# 78         Denmark  High income  2017
# 79         Denmark  High income  2018
# 85         Estonia  High income  2014
# 86         Estonia  High income  2015
# 87         Estonia  High income  2016
# 88         Estonia  High income  2017
# 89         Estonia  High income  2018
# 155         Latvia  High income  2014
# 156         Latvia  High income  2015
# 157         Latvia  High income  2016
# 158         Latvia  High income  2017
# 159         Latvia  High income  2018
# 185          Malta  High income  2014
# 186          Malta  High income  2015
# 187          Malta  High income  2016
# 188          Malta  High income  2017
# 189          Malta  High income  2018
# 236         Norway  High income  2015
# 237         Norway  High income  2016
# 238         Norway  High income  2017
# ...

# %%
High_income_sub['difference_to_average_directors']  = High_income_sub['difference_to_average_directors'].astype(int)
# Out:
# <ipython-input-68-dce237369dab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   High_income_sub['difference_to_average_directors']  = High_income_sub['difference_to_average_directors'].astype(int)

# %%
High_income_sub
# Out:
#            Country Income_group  Year  \
# 75         Denmark  High income  2014
# 76         Denmark  High income  2015
# 77         Denmark  High income  2016
# 78         Denmark  High income  2017
# 79         Denmark  High income  2018
# 85         Estonia  High income  2014
# 86         Estonia  High income  2015
# 87         Estonia  High income  2016
# 88         Estonia  High income  2017
# 89         Estonia  High income  2018
# 155         Latvia  High income  2014
# 156         Latvia  High income  2015
# 157         Latvia  High income  2016
# 158         Latvia  High income  2017
# 159         Latvia  High income  2018
# 185          Malta  High income  2014
# 186          Malta  High income  2015
# 187          Malta  High income  2016
# 188          Malta  High income  2017
# 189          Malta  High income  2018
# 236         Norway  High income  2015
# 237         Norway  High income  2016
# 238         Norway  High income  2017
# ...

# %%
High_income_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 75 to 329
# Data columns (total 19 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      44 non-null     object
#  1   Income_group                                 44 non-null     object
#  2   Year                                         44 non-null     int32
#  3   Number_of_female_business_owners_of_new_LLC  44 non-null     int32
#  4   Number_of_male_business_owners_of_new_LLC    44 non-null     int32
#  5   Total_number_of_business_owners_of_new_LLC   44 non-null     int32
#  6   Number_of_female_sole_proprietors            44 non-null     int32
#  7   Number_of_male_sole_proprietors              44 non-null     int32
#  8   Total_number_of_sole_proprietors             44 non-null     int32
# ...

# %%
Low_income_sub = female_business_owner_drop_renamed.query('Income_group == "Low income"')
Low_income_sub.head(2)
# Out:
#        Country Income_group  Year  \
# 0  Afghanistan   Low income  2014
# 1  Afghanistan   Low income  2015
#
#    Number_of_female_business_owners_of_new_LLC  \
# 0                                           65
# 1                                           45
#
#    Number_of_male_business_owners_of_new_LLC  \
# 0                                       5043
# 1                                       4704
#
#    Total_number_of_business_owners_of_new_LLC  \
# 0                                        5108
# 1                                        4749
#
#    Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 0                                 14                             2117
# 1                                 26                             3110
#
#    Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LLC  \
# 0                              2131                                     34
# ...

# %%
Lower_middle_income_sub = female_business_owner_drop_renamed.query('Income_group == "Lower middle income"')
Lower_middle_income_sub.head(2)
# Out:
#           Country         Income_group  Year  \
# 65  Cote d'Ivoire  Lower middle income  2014
# 66  Cote d'Ivoire  Lower middle income  2015
#
#     Number_of_female_business_owners_of_new_LLC  \
# 65                                         1525
# 66                                         1181
#
#     Number_of_male_business_owners_of_new_LLC  \
# 65                                       6509
# 66                                       5595
#
#     Total_number_of_business_owners_of_new_LLC  \
# 65                                        8034
# 66                                        6776
#
#     Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 65                                678                             1840
# 66                                894                             2443
#
#     Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LLC  \
# 65                              2518                                    678
# ...

# %%
Upper_middle_income_sub = female_business_owner_drop_renamed.query('Income_group == "Upper middle income"')
Upper_middle_income_sub.head(2)
# Out:
#    Country         Income_group  Year  \
# 5  Albania  Upper middle income  2014
# 6  Albania  Upper middle income  2015
#
#    Number_of_female_business_owners_of_new_LLC  \
# 5                                          401
# 6                                          457
#
#    Number_of_male_business_owners_of_new_LLC  \
# 5                                       1818
# 6                                       2159
#
#    Total_number_of_business_owners_of_new_LLC  \
# 5                                        2219
# 6                                        2616
#
#    Number_of_female_sole_proprietors  Number_of_male_sole_proprietors  \
# 5                               4984                             8812
# 6                              13317                            23649
#
#    Total_number_of_sole_proprietors  Number_of_female_directors_of_new_LLC  \
# 5                             13796                                    344
# ...

# %%
fem_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group', 'Year'], as_index=False)['Number_of_female_business_owners_of_new_LLC'].mean())
fem_LLCs_income_year.head(2)
# Out:
#   Income_group  Year  Number_of_female_business_owners_of_new_LLC
# 0  High income  2014                                  3271.750000
# 1  High income  2015                                  3427.666667

# %%
male_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Number_of_male_business_owners_of_new_LLC'].mean())
male_LLCs_income
# Out:
#           Income_group  Number_of_male_business_owners_of_new_LLC
# 0          High income                               11594.977273
# 1           Low income                                7801.733333
# 2  Lower middle income                               62733.800000
# 3  Upper middle income                               17967.072727

# %%
male_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group','Year'], as_index=False)['Number_of_male_business_owners_of_new_LLC'].mean())
male_LLCs_income_year
# Out:
#            Income_group  Year  Number_of_male_business_owners_of_new_LLC
# 0           High income  2014                                8799.875000
# 1           High income  2015                               10032.111111
# 2           High income  2016                               12287.888889
# 3           High income  2017                               13168.888889
# 4           High income  2018                               13375.555556
# 5            Low income  2014                                6158.666667
# 6            Low income  2015                                6045.666667
# 7            Low income  2016                                7538.333333
# 8            Low income  2017                                8488.666667
# 9            Low income  2018                               10777.333333
# 10  Lower middle income  2014                                8995.750000
# 11  Lower middle income  2015                               66312.400000
# ...

# %%
total_LLCs_income = (female_business_owner_drop_renamed.groupby(['Income_group'], as_index=False)['Total_number_of_business_owners_of_new_LLC'].mean())
total_LLCs_income
# Out:
#           Income_group  Total_number_of_business_owners_of_new_LLC
# 0          High income                                15471.227273
# 1           Low income                                 8828.800000
# 2  Lower middle income                                92102.760000
# 3  Upper middle income                                26146.090909

# %%
total_LLCs_income_year = (female_business_owner_drop_renamed.groupby(['Income_group','Year'], as_index=False)['Total_number_of_business_owners_of_new_LLC'].mean())
total_LLCs_income_year
# Out:
#            Income_group  Year  Total_number_of_business_owners_of_new_LLC
# 0           High income  2014                                12071.625000
# 1           High income  2015                                13459.777778
# 2           High income  2016                                16337.444444
# 3           High income  2017                                17456.777778
# 4           High income  2018                                17652.777778
# 5            Low income  2014                                 6893.666667
# 6            Low income  2015                                 6891.000000
# 7            Low income  2016                                 8603.000000
# 8            Low income  2017                                 9634.333333
# 9            Low income  2018                                12122.000000
# 10  Lower middle income  2014                                11969.500000
# 11  Lower middle income  2015                                97417.400000
# ...

# %%
female_business_owner_drop_renamed.Country.value_counts()
# Out:
# Cote d'Ivoire      5
# Azerbaijan         5
# Latvia             5
# Estonia            5
# Taiwan, China      5
# Denmark            5
# Malta              5
# Mongolia           5
# Serbia             5
# Georgia            5
# Nepal              5
# Zambia             5
# Algeria            5
# Slovenia           5
# Oman               5
# Mauritius          5
# Tajikistan         5
# Lao PDR            5
# Qatar              5
# Jamaica            5
# North Macedonia    5
# Romania            5
# Afghanistan        5
# Belarus            5
# Malaysia           5
# Albania            5
# Nigeria            4
# Norway             4
# Morocco            1
# Name: Country, dtype: int64

# %%
female_business_owner_drop_renamed.Income_group.value_counts()
# Out:
# Upper middle income    55
# High income            44
# Lower middle income    25
# Low income             15
# Name: Income_group, dtype: int64
