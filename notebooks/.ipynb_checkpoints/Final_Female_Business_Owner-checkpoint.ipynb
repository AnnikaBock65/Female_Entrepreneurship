# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
female_business_owner = pd.read_csv('../data/female_business_owner_data.csv', engine='python')
female_business_owner.shape
# Out:
# (379, 18)

# %%
female_business_owner.head()
# Out:
#        Country Income group    Year  \
# 0  Afghanistan   Low income  2014.0
# 1  Afghanistan   Low income  2015.0
# 2  Afghanistan   Low income  2016.0
# 3  Afghanistan   Low income  2017.0
# 4  Afghanistan   Low income  2018.0
#
#   Number of female business owners of new LLCs  \
# 0                                           65
# 1                                           45
# 2                                           65
# 3                                           88
# 4                                          177
#
#   Number of male business owners of new LLCs  \
# 0                                      5,043
# 1                                      4,704
# 2                                      5,036
# 3                                      6,047
# 4                                      8,482
#
#   Total number of business owners of new LLCs  \
# 0                                       5,108
# 1                                       4,749
# ...

# %%
female_business_owner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       365 non-null    object
#  1   Income group                                  365 non-null    object
#  2   Year                                          365 non-null    float64
#  3   Number of female business owners of new LLCs  250 non-null    object
#  4   Number of male business owners of new LLCs    250 non-null    object
#  5   Total number of business owners of new LLCs   250 non-null    object
#  6   Number of female sole proprietors             249 non-null    object
#  7   Number of male sole proprietors               249 non-null    object
#  8   Total number of sole proprietors              249 non-null    object
# ...

# %%
female_business_owner.isnull().sum()
# Out:
# Country                                          14
# Income group                                     14
# Year                                             14
# Number of female business owners of new LLCs    129
# Number of male business owners of new LLCs      129
# Total number of business owners of new LLCs     129
# Number of female sole proprietors               130
# Number of male sole proprietors                 130
# Total number of sole proprietors                130
# Number of female directors of new LCCS          177
# Number of male directors of new LCCS            177
# Total number of directors of new LCCS           177
# Share of female business owners of new LLCs     129
# Share of male business owners of new LLCs       129
# Share of female sole proprietors                130
# Share of male sole proprietors                  130
# Share of female directors of new LCCs           200
# Share of male directors of new LCCs             200
# dtype: int64

# %%
female_business_owner_drop = female_business_owner.dropna()

# %%
female_business_owner_drop.isnull().sum()
# Out:
# Country                                         0
# Income group                                    0
# Year                                            0
# Number of female business owners of new LLCs    0
# Number of male business owners of new LLCs      0
# Total number of business owners of new LLCs     0
# Number of female sole proprietors               0
# Number of male sole proprietors                 0
# Total number of sole proprietors                0
# Number of female directors of new LCCS          0
# Number of male directors of new LCCS            0
# Total number of directors of new LCCS           0
# Share of female business owners of new LLCs     0
# Share of male business owners of new LLCs       0
# Share of female sole proprietors                0
# Share of male sole proprietors                  0
# Share of female directors of new LCCs           0
# Share of male directors of new LCCs             0
# dtype: int64

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop.tail()
# Out:
#     Country         Income group    Year  \
# 360  Zambia  Lower middle income  2014.0
# 361  Zambia  Lower middle income  2015.0
# 362  Zambia  Lower middle income  2016.0
# 363  Zambia  Lower middle income  2017.0
# 364  Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 360                                        4,611
# 361                                        4,627
# 362                                        4,041
# 363                                        4,059
# 364                                        4,481
#
#     Number of male business owners of new LLCs  \
# 360                                     17,184
# 361                                     15,545
# 362                                     13,905
# 363                                     14,931
# 364                                     16,092
#
#     Total number of business owners of new LLCs  \
# 360                                      21,795
# ...

# %%
female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].str.replace('%', '')
# Out:
# <ipython-input-10-9ed9873abcb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].str.replace('%', '')
# Out:
# <ipython-input-11-e4411c152b59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-12-21bbfdc729c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')
# Out:
# <ipython-input-13-6f60126ae5f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].str.replace('%', '')

# %%
female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].str.replace('%', '')
# Out:
# <ipython-input-14-69278af0122d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].str.replace('%', '')

# %%
female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].str.replace('%', '')
# Out:
# <ipython-input-15-0122408e40c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].str.replace('%', '')

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    float64
#  3   Number of female business owners of new LLCs  139 non-null    object
#  4   Number of male business owners of new LLCs    139 non-null    object
#  5   Total number of business owners of new LLCs   139 non-null    object
#  6   Number of female sole proprietors             139 non-null    object
#  7   Number of male sole proprietors               139 non-null    object
#  8   Total number of sole proprietors              139 non-null    object
# ...

# %%
female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].astype(float)
# Out:
# <ipython-input-18-543dc57ac27a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male directors of new LCCs'] = female_business_owner_drop['Share of male directors of new LCCs'].astype(float)

# %%
female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].astype(float)
# Out:
# <ipython-input-19-2981b4115821>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female directors of new LCCs'] = female_business_owner_drop['Share of female directors of new LCCs'].astype(float)

# %%
female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)
# Out:
# <ipython-input-20-2ef0581b24e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male sole proprietors'] = female_business_owner_drop['Share of male sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)
# Out:
# <ipython-input-21-d20f7bc39483>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female sole proprietors'] = female_business_owner_drop['Share of female sole proprietors'].astype(float)

# %%
female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].astype(float)
# Out:
# <ipython-input-22-220c018adb67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of male business owners of new LLCs'] = female_business_owner_drop['Share of male business owners of new LLCs'].astype(float)

# %%
female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].astype(float)
# Out:
# <ipython-input-23-787f0f162b30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Share of female business owners of new LLCs'] = female_business_owner_drop['Share of female business owners of new LLCs'].astype(float)

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].str.replace(',', '')
# Out:
# <ipython-input-26-9ae5ebb32d0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].str.replace(',', '')

# %%
female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].astype(int)
# Out:
# <ipython-input-27-c3b5de7c14fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of directors of new LCCS'] = female_business_owner_drop['Total number of directors of new LCCS'].astype(int)

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].str.replace(',', '')
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].str.replace(',', '')
female_business_owner_drop['Total number of business owners of new LLCs'] = female_business_owner_drop['Total number of business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of male business owners of new LLCs'] = female_business_owner_drop['Number of male business owners of new LLCs'].str.replace(',', '')
female_business_owner_drop['Number of female directors of new LCCS'] = female_business_owner_drop['Number of female directors of new LCCS'].str.replace(',', '')
# Out:
# <ipython-input-29-b39d00e3635c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].str.replace(',', '')
# <ipython-input-29-b39d00e3635c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].str.replace(',', '')
# ...

# %%
female_business_owner_drop
# Out:
#          Country         Income group    Year  \
# 0    Afghanistan           Low income  2014.0
# 1    Afghanistan           Low income  2015.0
# 2    Afghanistan           Low income  2016.0
# 3    Afghanistan           Low income  2017.0
# 4    Afghanistan           Low income  2018.0
# ..           ...                  ...     ...
# 360       Zambia  Lower middle income  2014.0
# 361       Zambia  Lower middle income  2015.0
# 362       Zambia  Lower middle income  2016.0
# 363       Zambia  Lower middle income  2017.0
# 364       Zambia  Lower middle income  2018.0
#
#     Number of female business owners of new LLCs  \
# 0                                             65
# 1                                             45
# 2                                             65
# 3                                             88
# 4                                            177
# ..                                           ...
# 360                                        4,611
# ...

# %%
female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
female_business_owner_drop['Number of male sole proprietors'] = female_business_owner_drop['Number of male sole proprietors'].astype(int)
female_business_owner_drop['Number of female directors of new LCCS'] = female_business_owner_drop['Number of female directors of new LCCS'].astype(int)
# Out:
# <ipython-input-33-bcfac6e872e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Number of male directors of new LCCS'] = female_business_owner_drop['Number of male directors of new LCCS'].astype(int)
# <ipython-input-33-bcfac6e872e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_business_owner_drop['Total number of sole proprietors'] = female_business_owner_drop['Total number of sole proprietors'].astype(int)
# ...

# %%
female_business_owner_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country                                       139 non-null    object
#  1   Income group                                  139 non-null    object
#  2   Year                                          139 non-null    float64
#  3   Number of female business owners of new LLCs  139 non-null    object
#  4   Number of male business owners of new LLCs    139 non-null    object
#  5   Total number of business owners of new LLCs   139 non-null    object
#  6   Number of female sole proprietors             139 non-null    object
#  7   Number of male sole proprietors               139 non-null    int32
#  8   Total number of sole proprietors              139 non-null    int32
# ...
