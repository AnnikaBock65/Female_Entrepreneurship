# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_map = pd.read_csv('../data/Map_Tableau.csv', engine='python')
df_map.shape
# Out:
# (9500, 21)

# %%
df_map
# Out:
#       Unnamed: 0       ID      economy  latitude_x  longitude_x  \
# 0              0  AFG1972  Afghanistan   33.939110    67.709953
# 1              1  AFG1973  Afghanistan   33.939110    67.709953
# 2              2  AFG1974  Afghanistan   33.939110    67.709953
# 3              3  AFG1975  Afghanistan   33.939110    67.709953
# 4              4  AFG1976  Afghanistan   33.939110    67.709953
# ...          ...      ...          ...         ...          ...
# 9495        9495  ZWE2017     Zimbabwe  -19.015438    29.154857
# 9496        9496  ZWE2018     Zimbabwe  -19.015438    29.154857
# 9497        9497  ZWE2019     Zimbabwe  -19.015438    29.154857
# 9498        9498  ZWE2020     Zimbabwe  -19.015438    29.154857
# 9499        9499  ZWE2021     Zimbabwe  -19.015438    29.154857
#
#      country_code_x              Region         Income_group  reportyr  \
# 0               AFG          South Asia           Low income      1972
# ...

# %%
df_map = df_map.drop(columns = ['Unnamed: 0'])

# %%
df_map
# Out:
#            ID      economy  latitude_x  longitude_x country_code_x  \
# 0     AFG1972  Afghanistan   33.939110    67.709953            AFG
# 1     AFG1973  Afghanistan   33.939110    67.709953            AFG
# 2     AFG1974  Afghanistan   33.939110    67.709953            AFG
# 3     AFG1975  Afghanistan   33.939110    67.709953            AFG
# 4     AFG1976  Afghanistan   33.939110    67.709953            AFG
# ...       ...          ...         ...          ...            ...
# 9495  ZWE2017     Zimbabwe  -19.015438    29.154857            ZWE
# 9496  ZWE2018     Zimbabwe  -19.015438    29.154857            ZWE
# 9497  ZWE2019     Zimbabwe  -19.015438    29.154857            ZWE
# 9498  ZWE2020     Zimbabwe  -19.015438    29.154857            ZWE
# 9499  ZWE2021     Zimbabwe  -19.015438    29.154857            ZWE
#
#                   Region         Income_group  reportyr  WBL INDEX  \
# 0             South Asia           Low income      1972       26.3
# ...

# %%
Law_data = pd.read_csv('../data/Legal_Basis_python.csv', engine='python')
Law_data.shape
# Out:
# (191, 6)

# %%
Law_data
# Out:
#     ï»¿EconomyCode           EconomyName  \
# 0      EconomyCode           EconomyName
# 1              AFG           Afghanistan
# 2              AGO                Angola
# 3              ALB               Albania
# 4              ARE  United Arab Emirates
# ..             ...                   ...
# 186            YEM           Yemen, Rep.
# 187            ZAF          South Africa
# 188            ZAR      Congo, Dem. Rep.
# 189            ZMB                Zambia
# 190            ZWE              Zimbabwe
#
#                                      Fam_A2F_Gender_LB  \
# 0    Legal Basis: Does the law prohibit discriminat...
# 1            No applicable provisions could be located
# 2    Penal Code, Art. 197; Central Bank of Angola, ...
# 3    Law on Protection from Discrimination, Arts. 1...
# 4    Central Bank of the UAE Notice No. CBUAE/BSD20...
# ..                                                 ...
# 186          No applicable provisions could be located
# ...

# %%
Law_data = Law_data.rename(columns = {'ï»¿EconomyCode':'country_code_x', 'EconomyName':'economy'})

# %%
Law_data.drop([0])
# Out:
#     country_code_x               economy  \
# 1              AFG           Afghanistan
# 2              AGO                Angola
# 3              ALB               Albania
# 4              ARE  United Arab Emirates
# 5              ARG             Argentina
# ..             ...                   ...
# 186            YEM           Yemen, Rep.
# 187            ZAF          South Africa
# 188            ZAR      Congo, Dem. Rep.
# 189            ZMB                Zambia
# 190            ZWE              Zimbabwe
#
#                                      Fam_A2F_Gender_LB  \
# 1            No applicable provisions could be located
# 2    Penal Code, Art. 197; Central Bank of Angola, ...
# 3    Law on Protection from Discrimination, Arts. 1...
# 4    Central Bank of the UAE Notice No. CBUAE/BSD20...
# 5            No applicable provisions could be located
# ..                                                 ...
# 186          No applicable provisions could be located
# ...

# %%
Law_data
# Out:
#     country_code_x               economy  \
# 0      EconomyCode           EconomyName
# 1              AFG           Afghanistan
# 2              AGO                Angola
# 3              ALB               Albania
# 4              ARE  United Arab Emirates
# ..             ...                   ...
# 186            YEM           Yemen, Rep.
# 187            ZAF          South Africa
# 188            ZAR      Congo, Dem. Rep.
# 189            ZMB                Zambia
# 190            ZWE              Zimbabwe
#
#                                      Fam_A2F_Gender_LB  \
# 0    Legal Basis: Does the law prohibit discriminat...
# 1            No applicable provisions could be located
# 2    Penal Code, Art. 197; Central Bank of Angola, ...
# 3    Law on Protection from Discrimination, Arts. 1...
# 4    Central Bank of the UAE Notice No. CBUAE/BSD20...
# ..                                                 ...
# 186          No applicable provisions could be located
# ...

# %%
Law_data.tail()
# Out:
#     country_code_x           economy  \
# 186            YEM       Yemen, Rep.
# 187            ZAF      South Africa
# 188            ZAR  Congo, Dem. Rep.
# 189            ZMB            Zambia
# 190            ZWE          Zimbabwe
#
#                                      Fam_A2F_Gender_LB  \
# 186          No applicable provisions could be located
# 187               National Credit Act of 2006, Art. 61
# 188  Loi No. 15/013 du 1er AoÃ»t 2015 Portant Modal...
# 189    Gender Equity and Equality Act, Arts. 14 and 37
# 190  Prevention of Discrimination Act, Secs. 2(b), ...
#
#                                 Fam_CM_SignContract_SC  \
# 186                  No restrictions could be located
# 187                  No restrictions could be located
# 188  Loi No. 16/008, Art. 1 (Modifiant Art. 448) et...
# 189      Gender Equity and Equality Act, Art. 14(2)(a)
# 190                   No restrictions could be located
#
#                                  Fam_CM_RegisterBiz_LB  \
# ...

# %%
df_Map_with_Law = df_map.merge(Law_data, on = ['economy', 'country_code_x'], how = 'outer')

# %%
df_Map_with_Law
# Out:
#            ID                   economy  latitude_x  longitude_x  \
# 0     AFG1972               Afghanistan   33.939110    67.709953
# 1     AFG1973               Afghanistan   33.939110    67.709953
# 2     AFG1974               Afghanistan   33.939110    67.709953
# 3     AFG1975               Afghanistan   33.939110    67.709953
# 4     AFG1976               Afghanistan   33.939110    67.709953
# ...       ...                       ...         ...          ...
# 9499  ZWE2021                  Zimbabwe  -19.015438    29.154857
# 9500      NaN               EconomyName         NaN          NaN
# 9501      NaN            CÃ´te d'Ivoire         NaN          NaN
# 9502      NaN               Puerto Rico         NaN          NaN
# 9503      NaN  SÃ£o TomÃ© and PrÃ­ncipe         NaN          NaN
#
#      country_code_x              Region         Income_group  reportyr  \
# 0               AFG          South Asia           Low income    1972.0
# ...

# %%
df_Map_with_Law = df_Map_with_Law.iloc[0:9500,0:24]
df_Map_with_Law
# Out:
#            ID      economy  latitude_x  longitude_x country_code_x  \
# 0     AFG1972  Afghanistan   33.939110    67.709953            AFG
# 1     AFG1973  Afghanistan   33.939110    67.709953            AFG
# 2     AFG1974  Afghanistan   33.939110    67.709953            AFG
# 3     AFG1975  Afghanistan   33.939110    67.709953            AFG
# 4     AFG1976  Afghanistan   33.939110    67.709953            AFG
# ...       ...          ...         ...          ...            ...
# 9495  ZWE2017     Zimbabwe  -19.015438    29.154857            ZWE
# 9496  ZWE2018     Zimbabwe  -19.015438    29.154857            ZWE
# 9497  ZWE2019     Zimbabwe  -19.015438    29.154857            ZWE
# 9498  ZWE2020     Zimbabwe  -19.015438    29.154857            ZWE
# 9499  ZWE2021     Zimbabwe  -19.015438    29.154857            ZWE
#
#                   Region         Income_group  reportyr  WBL INDEX  \
# 0             South Asia           Low income    1972.0       26.3
# ...

# %%
df_Map_with_Law.to_csv('FINAL_Data_Map_with_Law.csv')
